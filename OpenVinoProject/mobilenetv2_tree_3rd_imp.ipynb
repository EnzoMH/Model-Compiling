# %% [markdown]
# # 3rd Attempt Mobilenet V2 Improvement Process

# %% [markdown]
# # 0. 라이브러리 임포트

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from google.colab import drive
from tensorflow.keras.applications import MobileNet
import re
import subprocess
from pathlib import Path
from typing import List, Optional
import tensorflow as tf
import tensorflow_datasets as tfds
from tqdm import tqdm

# %% [markdown]
# # 1. 데이터 로딩
#  - Convert color BGR to YUV
#  - Labeling

# %%
# 코랩 파일 마운트
drive.mount('/content/drive')

def loadfile(path):
    X = []
    Y = []

    for label in ('danger_key', 'danger', 'danger_st', 'danger_wi','normal' ,'warnning_both','warnning_leaf','warnning_sq') :
        print("Loading training images for the label: " + label)

        for filename in os.listdir(path + label + "/"):
            img = cv2.imread(path + label + "/" + filename)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
            img[:,:,0] = cv2.equalizeHist(img[:,:,0])
            img = cv2.cvtColor(img, cv2.COLOR_YUV2BGR)
            img = cv2.resize(img, (224, 224))
            X.append(img)
            if label == 'danger':
                Y.append(0)
            elif label == 'danger_key':
                Y.append(1)
            elif label == 'danger_st':
                Y.append(2)
            elif label == 'danger_wi':
                Y.append(3)
            elif label == 'normal':
                Y.append(4)
            elif label == 'warnning_sq':
                Y.append(5)
            elif label == 'warnning_leaf':
                Y.append(6)
            elif label == 'warnning_both':
                Y.append(7)


    X = np.array(X)
    Y = np.array(Y)

    return X, Y
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. 데이터 전처리
# - Train, Validation Split
#  - Split rate - Train : Validation = 7:3
# - Data Augmentation
#  - 회전범위 증가, 전단 변환 추가, 줌 추가

# %%
# 데이터 불러오기
X, y = loadfile('/content/drive/MyDrive/data/')

# Train : Val = 0.7 : 0.3로 데이터 세트 분리
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# 정규화
X_train = X_train.astype('float32') / 255
X_val = X_val.astype('float32') / 255

# 데이터 증강
# 회전범위 증가(20-40),전단변화 추가, 줌 추가
datagen = ImageDataGenerator(
    rotation_range=40,  # 회전 범위 증가
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,  # 전단 변환 추가
    zoom_range=0.2,  # 줌 추가
    horizontal_flip=True,
    fill_mode='nearest'  # 새로 생성된 픽셀을 채우는 방법
)

# Compute quantities required for featurewise normalization
datagen.fit(X_train)
# Out:
# Loading training images for the label: danger_key
# Loading training images for the label: danger
# Loading training images for the label: danger_st
# Loading training images for the label: danger_wi
# Loading training images for the label: normal
# Loading training images for the label: warnning_both
# Loading training images for the label: warnning_leaf
# Loading training images for the label: warnning_sq

# %% [markdown]
# - 전처리 된 이미지 확인

# %%
# 전처리 된 후 이미지 샘플 랜덤으로 10장 확인

import random
import matplotlib.pyplot as plt

sample_images = random.sample(range(len(X_train)), 10)

plt.figure(figsize=(15, 5))
for i, idx in enumerate(sample_images):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[idx])
    plt.title(f"Label: {y_train[idx]}")
    plt.axis('off')
plt.show()

# %% [markdown]
# # 3. MobilenetV2 Modeling

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense

# Build model
model = Sequential()
model.add(MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights='imagenet'))  # Use MobileNet
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))  # Increase dropout
model.add(Dense(512, activation='relu')) # 128 -> 512  변화
model.add(BatchNormalization())
model.add(Dense(8, activation='softmax')) # Class 조정 3 -> 8

# 모델 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 512)               655872
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dense_1 (Dense)             (None, 8)                 4104
#
# =================================================================
# Total params: 2920008 (11.14 MB)
# Trainable params: 2884872 (11.00 MB)
# Non-trainable params: 35136 (137.25 KB)
# _________________________________________________________________

# %%
# 모델 저장코드
# model.save('/content/drive/MyDrive/240109_1600.h5')
# tf.saved_model.save(model, '240109_1600')

# %% [markdown]
# # 조기종료 콜백함수 설정
#  - Val_loss, Val_Accuracy 개선되지 않을 시 조기종료 활성화, 단 90번

# %%
from tensorflow.keras.callbacks import Callback

class CustomEarlyStopping(Callback):
    def __init__(self, patience=0):
        super(CustomEarlyStopping, self).__init__()
        self.patience = patience
        # 조기 종료를 위한 카운터
        self.best_weights = None  # 최고 성능의 가중치 저장

    def on_train_begin(self, logs=None):
        # 최소 손실을 추적
        self.best = np.Inf
        self.wait = 0  # 현재 대기 시간

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        current_accuracy = logs.get('val_accuracy')
        # 조건에 따른 조기 종료 검사
        if np.less(current_loss, self.best) and np.greater(current_accuracy, 0.90):  # 예를 들어 정확도 90% 이상
            self.best = current_loss
            self.wait = 0
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.model.stop_training = True
                print(f'조기 종료됨: epoch {epoch}')
                # 최고 성능 가중치로 모델 복원
                self.model.set_weights(self.best_weights)

# 콜백 인스턴스 생성
custom_early_stopping = CustomEarlyStopping(patience=100)

# %% [markdown]
# # 4. Train

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# 모델 체크포인트 콜백 설정
checkpoint = ModelCheckpoint(
    'mobilenetv2_tree_3rd.h5',  # 저장될 파일 이름
    monitor='val_loss',           # 모니터링할 값
    save_best_only=True,          # 가장 좋은 모델만 저장
    verbose=1                     # 진행 상황을 출력
)

# 모델 훈련
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=8),
    steps_per_epoch=len(X_train) / 8,
    epochs=100,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint, custom_early_stopping]  # 콜백 추가
)
# Out:
# Epoch 1/100
# 75/74 [==============================] - ETA: 0s - loss: 2.3678 - accuracy: 0.2955
# Epoch 1: val_loss improved from inf to 4.43092, saving model to mobilenetv2_tree_3rd.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 74/74 [==============================] - 46s 189ms/step - loss: 2.3678 - accuracy: 0.2955 - val_loss: 4.4309 - val_accuracy: 0.3372
# Epoch 2/100
# 75/74 [==============================] - ETA: 0s - loss: 1.7257 - accuracy: 0.4457
# Epoch 2: val_loss did not improve from 4.43092
# 74/74 [==============================] - 11s 141ms/step - loss: 1.7257 - accuracy: 0.4457 - val_loss: 9.1029 - val_accuracy: 0.0465
# Epoch 3/100
# 75/74 [==============================] - ETA: 0s - loss: 1.4635 - accuracy: 0.4958
# Epoch 3: val_loss did not improve from 4.43092
# 74/74 [==============================] - 8s 111ms/step - loss: 1.4635 - accuracy: 0.4958 - val_loss: 6.1163 - val_accuracy: 0.1085
# Epoch 4/100
# 75/74 [==============================] - ETA: 0s - loss: 1.4854 - accuracy: 0.5058
# Epoch 4: val_loss did not improve from 4.43092
# 74/74 [==============================] - 10s 129ms/step - loss: 1.4854 - accuracy: 0.5058 - val_loss: 6.6548 - val_accuracy: 0.1473
# Epoch 5/100
# 75/74 [==============================] - ETA: 0s - loss: 1.2657 - accuracy: 0.5743
# Epoch 5: val_loss did not improve from 4.43092
# 74/74 [==============================] - 11s 141ms/step - loss: 1.2657 - accuracy: 0.5743 - val_loss: 6.8382 - val_accuracy: 0.0388
# Epoch 6/100
# 75/74 [==============================] - ETA: 0s - loss: 1.2782 - accuracy: 0.5643
# Epoch 6: val_loss improved from 4.43092 to 1.93742, saving model to mobilenetv2_tree_3rd.h5
# 74/74 [==============================] - 9s 119ms/step - loss: 1.2782 - accuracy: 0.5643 - val_loss: 1.9374 - val_accuracy: 0.4806
# Epoch 7/100
# 75/74 [==============================] - ETA: 0s - loss: 1.2424 - accuracy: 0.5776
# Epoch 7: val_loss did not improve from 1.93742
# 74/74 [==============================] - 10s 134ms/step - loss: 1.2424 - accuracy: 0.5776 - val_loss: 2.5986 - val_accuracy: 0.4225
# Epoch 8/100
# 75/74 [==============================] - ETA: 0s - loss: 1.1938 - accuracy: 0.6010
# Epoch 8: val_loss did not improve from 1.93742
# 74/74 [==============================] - 13s 168ms/step - loss: 1.1938 - accuracy: 0.6010 - val_loss: 5.6922 - val_accuracy: 0.2132
# Epoch 9/100
# 75/74 [==============================] - ETA: 0s - loss: 1.1125 - accuracy: 0.6244
# Epoch 9: val_loss did not improve from 1.93742
# 74/74 [==============================] - 8s 109ms/step - loss: 1.1125 - accuracy: 0.6244 - val_loss: 7.9562 - val_accuracy: 0.1202
# Epoch 10/100
# 75/74 [==============================] - ETA: 0s - loss: 1.0043 - accuracy: 0.6811
# Epoch 10: val_loss did not improve from 1.93742
# 74/74 [==============================] - 10s 129ms/step - loss: 1.0043 - accuracy: 0.6811 - val_loss: 20.2852 - val_accuracy: 0.0388
# Epoch 11/100
# 75/74 [==============================] - ETA: 0s - loss: 1.1402 - accuracy: 0.6244
# Epoch 11: val_loss did not improve from 1.93742
# 74/74 [==============================] - 10s 138ms/step - loss: 1.1402 - accuracy: 0.6244 - val_loss: 12.4770 - val_accuracy: 0.0698
# Epoch 12/100
# 75/74 [==============================] - ETA: 0s - loss: 1.0917 - accuracy: 0.6227
# Epoch 12: val_loss did not improve from 1.93742
# 74/74 [==============================] - 8s 107ms/step - loss: 1.0917 - accuracy: 0.6227 - val_loss: 17.1623 - val_accuracy: 0.0388
# Epoch 13/100
# 75/74 [==============================] - ETA: 0s - loss: 1.0008 - accuracy: 0.6611
# Epoch 13: val_loss did not improve from 1.93742
# 74/74 [==============================] - 10s 138ms/step - loss: 1.0008 - accuracy: 0.6611 - val_loss: 16.4637 - val_accuracy: 0.0233
# Epoch 14/100
# 75/74 [==============================] - ETA: 0s - loss: 1.0037 - accuracy: 0.6628
# Epoch 14: val_loss did not improve from 1.93742
# 74/74 [==============================] - 10s 138ms/step - loss: 1.0037 - accuracy: 0.6628 - val_loss: 12.6756 - val_accuracy: 0.0891
# Epoch 15/100
# 75/74 [==============================] - ETA: 0s - loss: 0.9132 - accuracy: 0.7028
# Epoch 15: val_loss did not improve from 1.93742
# 74/74 [==============================] - 8s 111ms/step - loss: 0.9132 - accuracy: 0.7028 - val_loss: 7.5333 - val_accuracy: 0.1008
# Epoch 16/100
# 75/74 [==============================] - ETA: 0s - loss: 0.8566 - accuracy: 0.7195
# Epoch 16: val_loss did not improve from 1.93742
# 74/74 [==============================] - 11s 148ms/step - loss: 0.8566 - accuracy: 0.7195 - val_loss: 15.5510 - val_accuracy: 0.0388
# Epoch 17/100
# 75/74 [==============================] - ETA: 0s - loss: 0.8516 - accuracy: 0.7162
# Epoch 17: val_loss did not improve from 1.93742
# 74/74 [==============================] - 10s 137ms/step - loss: 0.8516 - accuracy: 0.7162 - val_loss: 5.0561 - val_accuracy: 0.3333
# Epoch 18/100
# 75/74 [==============================] - ETA: 0s - loss: 0.8232 - accuracy: 0.7329
# Epoch 18: val_loss did not improve from 1.93742
# 74/74 [==============================] - 8s 109ms/step - loss: 0.8232 - accuracy: 0.7329 - val_loss: 6.9183 - val_accuracy: 0.1783
# Epoch 19/100
# 75/74 [==============================] - ETA: 0s - loss: 0.8282 - accuracy: 0.7546
# Epoch 19: val_loss did not improve from 1.93742
# 74/74 [==============================] - 11s 144ms/step - loss: 0.8282 - accuracy: 0.7546 - val_loss: 7.3019 - val_accuracy: 0.1047
# Epoch 20/100
# 75/74 [==============================] - ETA: 0s - loss: 0.7941 - accuracy: 0.7462
# Epoch 20: val_loss did not improve from 1.93742
# 74/74 [==============================] - 9s 124ms/step - loss: 0.7941 - accuracy: 0.7462 - val_loss: 3.0959 - val_accuracy: 0.3915
# Epoch 21/100
# 75/74 [==============================] - ETA: 0s - loss: 0.7517 - accuracy: 0.7563
# Epoch 21: val_loss did not improve from 1.93742
# 74/74 [==============================] - 9s 122ms/step - loss: 0.7517 - accuracy: 0.7563 - val_loss: 2.3735 - val_accuracy: 0.5853
# Epoch 22/100
# 75/74 [==============================] - ETA: 0s - loss: 0.8299 - accuracy: 0.7295
# Epoch 22: val_loss did not improve from 1.93742
# 74/74 [==============================] - 11s 143ms/step - loss: 0.8299 - accuracy: 0.7295 - val_loss: 3.3568 - val_accuracy: 0.2868
# Epoch 23/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6734 - accuracy: 0.7730
# Epoch 23: val_loss did not improve from 1.93742
# 74/74 [==============================] - 8s 112ms/step - loss: 0.6734 - accuracy: 0.7730 - val_loss: 7.4554 - val_accuracy: 0.1202
# Epoch 24/100
# 75/74 [==============================] - ETA: 0s - loss: 0.7324 - accuracy: 0.7396
# Epoch 24: val_loss did not improve from 1.93742
# 74/74 [==============================] - 9s 123ms/step - loss: 0.7324 - accuracy: 0.7396 - val_loss: 12.8047 - val_accuracy: 0.0543
# Epoch 25/100
# 75/74 [==============================] - ETA: 0s - loss: 0.7313 - accuracy: 0.7596
# Epoch 25: val_loss did not improve from 1.93742
# 74/74 [==============================] - 10s 138ms/step - loss: 0.7313 - accuracy: 0.7596 - val_loss: 20.8117 - val_accuracy: 0.0233
# Epoch 26/100
# 75/74 [==============================] - ETA: 0s - loss: 0.7230 - accuracy: 0.7579
# Epoch 26: val_loss did not improve from 1.93742
# 74/74 [==============================] - 8s 108ms/step - loss: 0.7230 - accuracy: 0.7579 - val_loss: 4.4288 - val_accuracy: 0.2442
# Epoch 27/100
# 75/74 [==============================] - ETA: 0s - loss: 0.7727 - accuracy: 0.7513
# Epoch 27: val_loss did not improve from 1.93742
# 74/74 [==============================] - 11s 141ms/step - loss: 0.7727 - accuracy: 0.7513 - val_loss: 3.9099 - val_accuracy: 0.2907
# Epoch 28/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6160 - accuracy: 0.7997
# Epoch 28: val_loss did not improve from 1.93742
# 74/74 [==============================] - 9s 124ms/step - loss: 0.6160 - accuracy: 0.7997 - val_loss: 5.5382 - val_accuracy: 0.2636
# Epoch 29/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6862 - accuracy: 0.7913
# Epoch 29: val_loss did not improve from 1.93742
# 74/74 [==============================] - 8s 109ms/step - loss: 0.6862 - accuracy: 0.7913 - val_loss: 4.3248 - val_accuracy: 0.4186
# Epoch 30/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6382 - accuracy: 0.8013
# Epoch 30: val_loss did not improve from 1.93742
# 74/74 [==============================] - 10s 140ms/step - loss: 0.6382 - accuracy: 0.8013 - val_loss: 7.2897 - val_accuracy: 0.2713
# Epoch 31/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6650 - accuracy: 0.7763
# Epoch 31: val_loss did not improve from 1.93742
# 74/74 [==============================] - 9s 124ms/step - loss: 0.6650 - accuracy: 0.7763 - val_loss: 7.7422 - val_accuracy: 0.1705
# Epoch 32/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6602 - accuracy: 0.7997
# Epoch 32: val_loss did not improve from 1.93742
# 74/74 [==============================] - 8s 110ms/step - loss: 0.6602 - accuracy: 0.7997 - val_loss: 3.3544 - val_accuracy: 0.3721
# Epoch 33/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6568 - accuracy: 0.8013
# Epoch 33: val_loss improved from 1.93742 to 1.69287, saving model to mobilenetv2_tree_3rd.h5
# 74/74 [==============================] - 11s 143ms/step - loss: 0.6568 - accuracy: 0.8013 - val_loss: 1.6929 - val_accuracy: 0.6357
# Epoch 34/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6298 - accuracy: 0.8013
# Epoch 34: val_loss did not improve from 1.69287
# 74/74 [==============================] - 9s 122ms/step - loss: 0.6298 - accuracy: 0.8013 - val_loss: 5.7710 - val_accuracy: 0.4302
# Epoch 35/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5816 - accuracy: 0.8147
# Epoch 35: val_loss improved from 1.69287 to 1.29310, saving model to mobilenetv2_tree_3rd.h5
# 74/74 [==============================] - 12s 163ms/step - loss: 0.5816 - accuracy: 0.8147 - val_loss: 1.2931 - val_accuracy: 0.6705
# Epoch 36/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6779 - accuracy: 0.7880
# Epoch 36: val_loss did not improve from 1.29310
# 74/74 [==============================] - 11s 144ms/step - loss: 0.6779 - accuracy: 0.7880 - val_loss: 2.1639 - val_accuracy: 0.4341
# Epoch 37/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.8114
# Epoch 37: val_loss did not improve from 1.29310
# 74/74 [==============================] - 11s 145ms/step - loss: 0.6304 - accuracy: 0.8114 - val_loss: 1.7074 - val_accuracy: 0.5426
# Epoch 38/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6517 - accuracy: 0.7963
# Epoch 38: val_loss did not improve from 1.29310
# 74/74 [==============================] - 8s 108ms/step - loss: 0.6517 - accuracy: 0.7963 - val_loss: 3.9616 - val_accuracy: 0.2326
# Epoch 39/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5272 - accuracy: 0.8331
# Epoch 39: val_loss improved from 1.29310 to 1.18749, saving model to mobilenetv2_tree_3rd.h5
# 74/74 [==============================] - 10s 135ms/step - loss: 0.5272 - accuracy: 0.8331 - val_loss: 1.1875 - val_accuracy: 0.7558
# Epoch 40/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5626 - accuracy: 0.8280
# Epoch 40: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 143ms/step - loss: 0.5626 - accuracy: 0.8280 - val_loss: 7.4821 - val_accuracy: 0.1977
# Epoch 41/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6229 - accuracy: 0.8063
# Epoch 41: val_loss did not improve from 1.18749
# 74/74 [==============================] - 8s 111ms/step - loss: 0.6229 - accuracy: 0.8063 - val_loss: 3.8032 - val_accuracy: 0.3178
# Epoch 42/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6094 - accuracy: 0.8114
# Epoch 42: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 130ms/step - loss: 0.6094 - accuracy: 0.8114 - val_loss: 5.5053 - val_accuracy: 0.3992
# Epoch 43/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5947 - accuracy: 0.8264
# Epoch 43: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 139ms/step - loss: 0.5947 - accuracy: 0.8264 - val_loss: 2.2781 - val_accuracy: 0.5388
# Epoch 44/100
# 75/74 [==============================] - ETA: 0s - loss: 0.6775 - accuracy: 0.7746
# Epoch 44: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 121ms/step - loss: 0.6775 - accuracy: 0.7746 - val_loss: 6.5844 - val_accuracy: 0.3178
# Epoch 45/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4943 - accuracy: 0.8397
# Epoch 45: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 144ms/step - loss: 0.4943 - accuracy: 0.8397 - val_loss: 1.7668 - val_accuracy: 0.6628
# Epoch 46/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.8531
# Epoch 46: val_loss did not improve from 1.18749
# 74/74 [==============================] - 8s 106ms/step - loss: 0.4913 - accuracy: 0.8531 - val_loss: 2.9238 - val_accuracy: 0.3837
# Epoch 47/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5089 - accuracy: 0.8381
# Epoch 47: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 141ms/step - loss: 0.5089 - accuracy: 0.8381 - val_loss: 1.7479 - val_accuracy: 0.6512
# Epoch 48/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5200 - accuracy: 0.8548
# Epoch 48: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 142ms/step - loss: 0.5200 - accuracy: 0.8548 - val_loss: 1.7198 - val_accuracy: 0.6279
# Epoch 49/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5014 - accuracy: 0.8481
# Epoch 49: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 130ms/step - loss: 0.5014 - accuracy: 0.8481 - val_loss: 1.2543 - val_accuracy: 0.7016
# Epoch 50/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5213 - accuracy: 0.8414
# Epoch 50: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 143ms/step - loss: 0.5213 - accuracy: 0.8414 - val_loss: 1.5023 - val_accuracy: 0.7287
# Epoch 51/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4563 - accuracy: 0.8715
# Epoch 51: val_loss did not improve from 1.18749
# 74/74 [==============================] - 8s 107ms/step - loss: 0.4563 - accuracy: 0.8715 - val_loss: 3.2986 - val_accuracy: 0.3682
# Epoch 52/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4160 - accuracy: 0.8715
# Epoch 52: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 114ms/step - loss: 0.4160 - accuracy: 0.8715 - val_loss: 4.6244 - val_accuracy: 0.2442
# Epoch 53/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5373 - accuracy: 0.8180
# Epoch 53: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 139ms/step - loss: 0.5373 - accuracy: 0.8180 - val_loss: 2.3330 - val_accuracy: 0.6163
# Epoch 54/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5434 - accuracy: 0.8264
# Epoch 54: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 117ms/step - loss: 0.5434 - accuracy: 0.8264 - val_loss: 3.8152 - val_accuracy: 0.4070
# Epoch 55/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4772 - accuracy: 0.8414
# Epoch 55: val_loss did not improve from 1.18749
# 74/74 [==============================] - 8s 111ms/step - loss: 0.4772 - accuracy: 0.8414 - val_loss: 7.0985 - val_accuracy: 0.1860
# Epoch 56/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5007 - accuracy: 0.8214
# Epoch 56: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 139ms/step - loss: 0.5007 - accuracy: 0.8214 - val_loss: 2.1997 - val_accuracy: 0.6008
# Epoch 57/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5472 - accuracy: 0.8347
# Epoch 57: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 123ms/step - loss: 0.5472 - accuracy: 0.8347 - val_loss: 1.7943 - val_accuracy: 0.5543
# Epoch 58/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4699 - accuracy: 0.8598
# Epoch 58: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 121ms/step - loss: 0.4699 - accuracy: 0.8598 - val_loss: 3.5000 - val_accuracy: 0.2829
# Epoch 59/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5183 - accuracy: 0.8280
# Epoch 59: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 138ms/step - loss: 0.5183 - accuracy: 0.8280 - val_loss: 4.1021 - val_accuracy: 0.3023
# Epoch 60/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5456 - accuracy: 0.8264
# Epoch 60: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 116ms/step - loss: 0.5456 - accuracy: 0.8264 - val_loss: 1.5581 - val_accuracy: 0.6008
# Epoch 61/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4973 - accuracy: 0.8431
# Epoch 61: val_loss did not improve from 1.18749
# 74/74 [==============================] - 13s 170ms/step - loss: 0.4973 - accuracy: 0.8431 - val_loss: 2.6682 - val_accuracy: 0.4496
# Epoch 62/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.8497
# Epoch 62: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 131ms/step - loss: 0.4802 - accuracy: 0.8497 - val_loss: 4.7976 - val_accuracy: 0.3062
# Epoch 63/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4741 - accuracy: 0.8431
# Epoch 63: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 116ms/step - loss: 0.4741 - accuracy: 0.8431 - val_loss: 5.1543 - val_accuracy: 0.3023
# Epoch 64/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5218 - accuracy: 0.8497
# Epoch 64: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 142ms/step - loss: 0.5218 - accuracy: 0.8497 - val_loss: 2.4844 - val_accuracy: 0.4651
# Epoch 65/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5504 - accuracy: 0.8331
# Epoch 65: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 120ms/step - loss: 0.5504 - accuracy: 0.8331 - val_loss: 2.9711 - val_accuracy: 0.5194
# Epoch 66/100
# 75/74 [==============================] - ETA: 0s - loss: 0.5311 - accuracy: 0.8364
# Epoch 66: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 124ms/step - loss: 0.5311 - accuracy: 0.8364 - val_loss: 1.9927 - val_accuracy: 0.5891
# Epoch 67/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.8731
# Epoch 67: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 139ms/step - loss: 0.4298 - accuracy: 0.8731 - val_loss: 4.9983 - val_accuracy: 0.2481
# Epoch 68/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4698 - accuracy: 0.8631
# Epoch 68: val_loss did not improve from 1.18749
# 74/74 [==============================] - 8s 109ms/step - loss: 0.4698 - accuracy: 0.8631 - val_loss: 3.2361 - val_accuracy: 0.3915
# Epoch 69/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.8748
# Epoch 69: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 116ms/step - loss: 0.4365 - accuracy: 0.8748 - val_loss: 1.5216 - val_accuracy: 0.6783
# Epoch 70/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4137 - accuracy: 0.8798
# Epoch 70: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 139ms/step - loss: 0.4137 - accuracy: 0.8798 - val_loss: 4.8771 - val_accuracy: 0.3372
# Epoch 71/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4806 - accuracy: 0.8648
# Epoch 71: val_loss did not improve from 1.18749
# 74/74 [==============================] - 8s 113ms/step - loss: 0.4806 - accuracy: 0.8648 - val_loss: 3.4883 - val_accuracy: 0.3876
# Epoch 72/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4454 - accuracy: 0.8598
# Epoch 72: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 114ms/step - loss: 0.4454 - accuracy: 0.8598 - val_loss: 2.3119 - val_accuracy: 0.6550
# Epoch 73/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4197 - accuracy: 0.8681
# Epoch 73: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 141ms/step - loss: 0.4197 - accuracy: 0.8681 - val_loss: 1.7867 - val_accuracy: 0.6512
# Epoch 74/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4520 - accuracy: 0.8664
# Epoch 74: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 140ms/step - loss: 0.4520 - accuracy: 0.8664 - val_loss: 1.7333 - val_accuracy: 0.4961
# Epoch 75/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8915
# Epoch 75: val_loss did not improve from 1.18749
# 74/74 [==============================] - 8s 108ms/step - loss: 0.3438 - accuracy: 0.8915 - val_loss: 2.6556 - val_accuracy: 0.5426
# Epoch 76/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4963 - accuracy: 0.8631
# Epoch 76: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 147ms/step - loss: 0.4963 - accuracy: 0.8631 - val_loss: 4.1542 - val_accuracy: 0.4961
# Epoch 77/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.8631
# Epoch 77: val_loss did not improve from 1.18749
# 74/74 [==============================] - 10s 135ms/step - loss: 0.4096 - accuracy: 0.8631 - val_loss: 5.1393 - val_accuracy: 0.3682
# Epoch 78/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.8715
# Epoch 78: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 112ms/step - loss: 0.4275 - accuracy: 0.8715 - val_loss: 1.1893 - val_accuracy: 0.7868
# Epoch 79/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4755 - accuracy: 0.8481
# Epoch 79: val_loss did not improve from 1.18749
# 74/74 [==============================] - 11s 143ms/step - loss: 0.4755 - accuracy: 0.8481 - val_loss: 4.0500 - val_accuracy: 0.2868
# Epoch 80/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4660 - accuracy: 0.8514
# Epoch 80: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 125ms/step - loss: 0.4660 - accuracy: 0.8514 - val_loss: 4.2815 - val_accuracy: 0.5775
# Epoch 81/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3652 - accuracy: 0.8932
# Epoch 81: val_loss did not improve from 1.18749
# 74/74 [==============================] - 9s 115ms/step - loss: 0.3652 - accuracy: 0.8932 - val_loss: 2.9630 - val_accuracy: 0.4302
# Epoch 82/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3635 - accuracy: 0.8915
# Epoch 82: val_loss improved from 1.18749 to 0.97879, saving model to mobilenetv2_tree_3rd.h5
# 74/74 [==============================] - 11s 153ms/step - loss: 0.3635 - accuracy: 0.8915 - val_loss: 0.9788 - val_accuracy: 0.7636
# Epoch 83/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4560 - accuracy: 0.8598
# Epoch 83: val_loss did not improve from 0.97879
# 74/74 [==============================] - 11s 150ms/step - loss: 0.4560 - accuracy: 0.8598 - val_loss: 2.3805 - val_accuracy: 0.4884
# Epoch 84/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.8598
# Epoch 84: val_loss did not improve from 0.97879
# 74/74 [==============================] - 8s 110ms/step - loss: 0.4479 - accuracy: 0.8598 - val_loss: 1.6059 - val_accuracy: 0.5853
# Epoch 85/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4493 - accuracy: 0.8681
# Epoch 85: val_loss did not improve from 0.97879
# 74/74 [==============================] - 11s 146ms/step - loss: 0.4493 - accuracy: 0.8681 - val_loss: 1.2479 - val_accuracy: 0.7403
# Epoch 86/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.9048
# Epoch 86: val_loss did not improve from 0.97879
# 74/74 [==============================] - 11s 144ms/step - loss: 0.3249 - accuracy: 0.9048 - val_loss: 1.2527 - val_accuracy: 0.7713
# Epoch 87/100
# 75/74 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.9082
# Epoch 87: val_loss did not improve from 0.97879
# 74/74 [==============================] - 11s 141ms/step - loss: 0.2826 - accuracy: 0.9082 - val_loss: 0.9983 - val_accuracy: 0.7868
# Epoch 88/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4931 - accuracy: 0.8681
# Epoch 88: val_loss did not improve from 0.97879
# 74/74 [==============================] - 13s 178ms/step - loss: 0.4931 - accuracy: 0.8681 - val_loss: 3.7497 - val_accuracy: 0.4651
# Epoch 89/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.8898
# Epoch 89: val_loss did not improve from 0.97879
# 74/74 [==============================] - 9s 120ms/step - loss: 0.3801 - accuracy: 0.8898 - val_loss: 3.2064 - val_accuracy: 0.5426
# Epoch 90/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.8898
# Epoch 90: val_loss did not improve from 0.97879
# 74/74 [==============================] - 10s 133ms/step - loss: 0.3549 - accuracy: 0.8898 - val_loss: 2.3077 - val_accuracy: 0.6512
# Epoch 91/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8798
# Epoch 91: val_loss did not improve from 0.97879
# 74/74 [==============================] - 11s 143ms/step - loss: 0.4077 - accuracy: 0.8798 - val_loss: 4.2950 - val_accuracy: 0.5078
# Epoch 92/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4591 - accuracy: 0.8715
# Epoch 92: val_loss did not improve from 0.97879
# 74/74 [==============================] - 9s 115ms/step - loss: 0.4591 - accuracy: 0.8715 - val_loss: 1.3387 - val_accuracy: 0.7016
# Epoch 93/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8831
# Epoch 93: val_loss did not improve from 0.97879
# 74/74 [==============================] - 11s 143ms/step - loss: 0.3826 - accuracy: 0.8831 - val_loss: 1.2968 - val_accuracy: 0.7403
# Epoch 94/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.8831
# Epoch 94: val_loss improved from 0.97879 to 0.90875, saving model to mobilenetv2_tree_3rd.h5
# 74/74 [==============================] - 9s 124ms/step - loss: 0.3945 - accuracy: 0.8831 - val_loss: 0.9088 - val_accuracy: 0.7829
# Epoch 95/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3350 - accuracy: 0.8998
# Epoch 95: val_loss did not improve from 0.90875
# 74/74 [==============================] - 9s 113ms/step - loss: 0.3350 - accuracy: 0.8998 - val_loss: 1.4981 - val_accuracy: 0.7403
# Epoch 96/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4986 - accuracy: 0.8297
# Epoch 96: val_loss did not improve from 0.90875
# 74/74 [==============================] - 11s 149ms/step - loss: 0.4986 - accuracy: 0.8297 - val_loss: 1.9835 - val_accuracy: 0.6163
# Epoch 97/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3926 - accuracy: 0.8848
# Epoch 97: val_loss did not improve from 0.90875
# 74/74 [==============================] - 8s 110ms/step - loss: 0.3926 - accuracy: 0.8848 - val_loss: 2.1184 - val_accuracy: 0.5853
# Epoch 98/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4098 - accuracy: 0.8748
# Epoch 98: val_loss did not improve from 0.90875
# 74/74 [==============================] - 11s 145ms/step - loss: 0.4098 - accuracy: 0.8748 - val_loss: 1.3575 - val_accuracy: 0.7636
# Epoch 99/100
# 75/74 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.9032
# Epoch 99: val_loss did not improve from 0.90875
# 74/74 [==============================] - 9s 118ms/step - loss: 0.3307 - accuracy: 0.9032 - val_loss: 1.4689 - val_accuracy: 0.7597
# Epoch 100/100
# 75/74 [==============================] - ETA: 0s - loss: 0.4162 - accuracy: 0.8681
# Epoch 100: val_loss did not improve from 0.90875
# 조기 종료됨: epoch 99
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-9fde06c6bf76> in <cell line: 12>()
#      10
#      11 # 모델 훈련
# ---> 12 history = model.fit(
#      13     datagen.flow(X_train, y_train, batch_size=8),
#      14     steps_per_epoch=len(X_train) / 8,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# <ipython-input-8-af680b894866> in on_epoch_end(self, epoch, logs)
#      27                 print(f'조기 종료됨: epoch {epoch}')
#      28                 # 최고 성능 가중치로 모델 복원
# ---> 29                 self.model.set_weights(self.best_weights)
#      30
#      31 # 콜백 인스턴스 생성
#
# TypeError: object of type 'NoneType' has no len()

# %%
# tf.saved_model.save(model,'231205_1430')

# %% [markdown]
# # 5. 평가

# %%
from tensorflow.keras.models import load_model

# 최고 성능 모델 불러오기
best_model = load_model('mobilenetv2_tree_3rd.h5')

# 훈련 데이터와 검증 데이터에 대한 성능 평가
train_loss, train_accuracy = best_model.evaluate(X_train, y_train, verbose=0)
val_loss, val_accuracy = best_model.evaluate(X_val, y_val, verbose=0)

# 성능 시각화
plt.figure(figsize=(12, 6))

# 정확도 그래프
plt.subplot(1, 2, 1)
plt.bar(['Train', 'Validation'], [train_accuracy, val_accuracy], color=['blue', 'orange'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')

# 손실 그래프
plt.subplot(1, 2, 2)
plt.bar(['Train', 'Validation'], [train_loss, val_loss], color=['blue', 'orange'])
plt.title('Model Loss')
plt.ylabel('Loss')

plt.show()

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
class_names = ['danger', 'danger_key', 'danger_st', 'danger_wi', 'normal', 'warnning_both', 'warnning_leaf', 'warnning_sq']

# 최고 성능 모델 불러오기
best_model = load_model('mobilenetv2_tree_3rd.h5')

# 검증 데이터에 대한 예측 수행
y_pred = best_model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

# 혼동 행렬 생성
cm = confusion_matrix(y_val, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# 분류 보고서 생성
print(classification_report(y_val, y_pred_classes, target_names=class_names))
# Out:
# 9/9 [==============================] - 2s 51ms/step
#                precision    recall  f1-score   support
#
#        danger       0.79      0.89      0.84        64
#    danger_key       0.60      0.75      0.67         4
#     danger_st       0.80      0.80      0.80         5
#     danger_wi       0.15      0.40      0.22         5
#        normal       0.89      0.82      0.85        87
# warnning_both       0.89      0.69      0.78        36
# warnning_leaf       0.77      0.72      0.75        47
#   warnning_sq       0.55      0.60      0.57        10
#
#      accuracy                           0.78       258
#     macro avg       0.68      0.71      0.68       258
#  weighted avg       0.81      0.78      0.79       258

# %%
# 평가 시간 측정 및 용량 확인

import time
import os

def get_model_inference_time_and_size(model):
    # 모델 저장
    model_path = 'mobilenetv2_tree_3rd.h5'
    model.save(model_path)

    # 모델 파일 크기 확인 (MB 단위)
    model_size = os.path.getsize(model_path) / (1024 * 1024)

    # 추론 시간 측정
    num_samples = 50
    sample_images = random.sample(range(len(X_train)), num_samples)
    start_time = time.time()
    for idx in sample_images:
        _ = model.predict(np.expand_dims(X_train[idx], axis=0))
    end_time = time.time()
    inference_time_per_image = (end_time - start_time) / num_samples

    return model_size, inference_time_per_image

model_size, inference_time = get_model_inference_time_and_size(model)
print(f"Model Size: {model_size:.2f} MB")
print(f"Inference Time per Image: {inference_time * 1000:.2f} ms")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Model Size: 33.82 MB
# Inference Time per Image: 98.86 ms

# %%
from tensorflow.keras.models import load_model
import random
import numpy as np
import matplotlib.pyplot as plt

class_names = ['danger', 'danger_key', 'danger_st', 'danger_wi', 'normal', 'warnning_both', 'warnning_leaf', 'warnning_sq']

# 저장된 최고 성능 모델 불러오기
best_model = load_model('mobilenetv2_tree_3rd.h5')

# 50장의 무작위 테스트 이미지 선택
sample_images = random.sample(range(len(X_val)), 50)

correct_count = 0  # 정확하게 분류된 이미지 수

# 추론 및 결과 표시
plt.figure(figsize=(15, 15))
for i, idx in enumerate(sample_images):
    image = X_val[idx]
    true_label = y_val[idx]

    # 이미지 추론
    predicted_probs = best_model.predict(np.expand_dims(image, axis=0))
    predicted_label = np.argmax(predicted_probs)

    # 이미지와 추론 결과 표시
    plt.subplot(10, 5, i + 1)
    plt.imshow(image)
    plt.axis('off')
    if true_label == predicted_label:
        plt.title(f"Label: {class_names[true_label]}\nCorrect", color='green')
        correct_count += 1
    else:
        plt.title(f"Label: {class_names[true_label]}\nPredicted: {class_names[predicted_label]}", color='red')

plt.tight_layout()
plt.show()

# 정확도 출력
accuracy = (correct_count / len(sample_images)) * 100
print(f"추론 정확도: {accuracy:.2f}%")
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 추론 정확도: 58.00%

# %% [markdown]
# # 6. 최적화

# %%
import os
import re
import subprocess
from pathlib import Path
from typing import List, Optional
import openvino as ov
import tensorflow as tf
import tensorflow_datasets as tfds
from tqdm import tqdm
import nncf
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive')
#print('current:', os.getcwd())

ROOT = Path('/content/drive/MyDrive/mobilenetv2_tree_2nd').parent.resolve()
WEIGHTS_URL = "/content/drive/MyDrive/mobilenetv2_tree_2nd.h5"
DATASET_CLASSES = 8


def validate(model: ov.Model, val_loader: tf.data.Dataset) -> tf.Tensor:
    compiled_model = ov.compile_model(model)
    output = compiled_model.outputs[0]

    metric = tf.keras.metrics.CategoricalAccuracy(name="acc@1")
    for images, labels in tqdm(val_loader):
        pred = compiled_model(images.numpy())[output]
        metric.update_state(labels, pred)

    return metric.result()


def run_benchmark(model_path: str, shape: Optional[List[int]] = None, verbose: bool = True) -> float:
    command = f"benchmark_app -m {model_path} -d CPU -api async -t 15"
    if shape is not None:
        command += f' -shape [{",".join(str(x) for x in shape)}]'
    cmd_output = subprocess.check_output(command, shell=True)  # nosec
    if verbose:
        print(*str(cmd_output).split("\\n")[-9:-1], sep="\n")
    match = re.search(r"Throughput\: (.+?) FPS", str(cmd_output))
    return float(match.group(1))


def get_model_size(ir_path: str, m_type: str = "Mb", verbose: bool = True) -> float:
    xml_size = os.path.getsize(ir_path)
    bin_size = os.path.getsize(os.path.splitext(ir_path)[0] + ".bin")
    for t in ["bytes", "Kb", "Mb"]:
        if m_type == t:
            break
        xml_size /= 1024
        bin_size /= 1024
    model_size = xml_size + bin_size
    if verbose:
        print(f"Model graph (xml):   {xml_size:.3f} Mb")
        print(f"Model weights (bin): {bin_size:.3f} Mb")
        print(f"Model size:          {model_size:.3f} Mb")
    return model_size


###############################################################################
# Create a Tensorflow model and dataset


def center_crop(image: tf.Tensor, image_size: int, crop_padding: int) -> tf.Tensor:
    shape = tf.shape(image)
    image_height = shape[0]
    image_width = shape[1]

    padded_center_crop_size = tf.cast(
        ((image_size / (image_size + crop_padding)) * tf.cast(tf.minimum(image_height, image_width), tf.float32)),
        tf.int32,
    )

    offset_height = ((image_height - padded_center_crop_size) + 1) // 2
    offset_width = ((image_width - padded_center_crop_size) + 1) // 2

    image = tf.image.crop_to_bounding_box(
        image,
        offset_height=offset_height,
        offset_width=offset_width,
        target_height=padded_center_crop_size,
        target_width=padded_center_crop_size,
    )

    image = tf.compat.v1.image.resize(
        image, [image_size, image_size], method=tf.image.ResizeMethod.BILINEAR, align_corners=False
    )

    return image


def preprocess_for_eval(image, label):
    image = center_crop(image, 224, 32)
    image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
    image = tf.image.convert_image_dtype(image, tf.float32)

    label = tf.one_hot(label, DATASET_CLASSES)

    return image, label


val_dataset = tfds.load("imagenette/320px-v2", split="validation", shuffle_files=False, as_supervised=True)
val_dataset = val_dataset.map(preprocess_for_eval).batch(128)

weights_path = tf.keras.utils.get_file("/content/drive/MyDrive/mobilenetv2_tree_2nd", WEIGHTS_URL, cache_subdir="models")
tf_model = tf.keras.applications.MobileNetV2(weights=weights_path, classes=DATASET_CLASSES)

###############################################################################
# Quantize a Tensorflow model
#
# The transformation function transforms a data item into model input data.
#
# To validate the transform function use the following code:
# >> for data_item in val_loader:
# >>    model(transform_fn(data_item))


# def transform_fn(data_item):
#     images, _ = data_item
#     return images


# # The calibration dataset is a small, no label, representative dataset
# # (~100-500 samples) that is used to estimate the range, i.e. (min, max) of all
# # floating point activation tensors in the model, to initialize the quantization
# # parameters.
# #
# # The easiest way to define a calibration dataset is to use a training or
# # validation dataset and a transformation function to remove labels from the data
# # item and prepare model input data. The quantize method uses a small subset
# # (default: 300 samples) of the calibration dataset.

# calibration_dataset = nncf.Dataset(val_dataset, transform_fn)
# tf_quantized_model = nncf.quantize(tf_model, calibration_dataset)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Quantize a Tensorflow model
#
# The transformation function transforms a data item into model input data.
#
# To validate the transform function use the following code:
# >> for data_item in val_loader:
# >>    model(transform_fn(data_item))


def transform_fn(data_item):
    images, _ = data_item
    return images


# The calibration dataset is a small, no label, representative dataset
# (~100-500 samples) that is used to estimate the range, i.e. (min, max) of all
# floating point activation tensors in the model, to initialize the quantization
# parameters.
#
# The easiest way to define a calibration dataset is to use a training or
# validation dataset and a transformation function to remove labels from the data
# item and prepare model input data. The quantize method uses a small subset
# (default: 300 samples) of the calibration dataset.

calibration_dataset = nncf.Dataset(val_dataset, transform_fn)
tf_quantized_model = nncf.quantize(tf_model, calibration_dataset)

###############################################################################
# Benchmark performance, calculate compression rate and validate accuracy

ov_model = ov.convert_model(tf_model, share_weights=False)
#경량화 모델 : ov_quntized_model
ov_quantized_model = ov.convert_model(tf_quantized_model, share_weights=False)

fp32_ir_path = f"{ROOT}/mobilenet_v2_fp32.xml"
ov.save_model(ov_model, fp32_ir_path, compress_to_fp16=False)
print(f"[1/7] Save FP32 model: {fp32_ir_path}")
fp32_model_size = get_model_size(fp32_ir_path, verbose=True)

int8_ir_path = f"{ROOT}/mobilenet_v2_int8.xml"
ov.save_model(ov_quantized_model, int8_ir_path, compress_to_fp16=False)
print(f"[2/7] Save INT8 model: {int8_ir_path}")
int8_model_size = get_model_size(int8_ir_path, verbose=True)

print("[3/7] Benchmark FP32 model:")
fp32_fps = run_benchmark(fp32_ir_path, shape=[1, 224, 224, 3], verbose=True)
print("[4/7] Benchmark INT8 model:")
int8_fps = run_benchmark(int8_ir_path, shape=[1, 224, 224, 3], verbose=True)

print("[5/7] Validate OpenVINO FP32 model:")
fp32_top1 = validate(ov_model, val_dataset)
print(f"Accuracy @ top1: {fp32_top1:.3f}")

print("[6/7] Validate OpenVINO INT8 model:")
int8_top1 = validate(ov_quantized_model, val_dataset)
print(f"Accuracy @ top1: {int8_top1:.3f}")

print("[7/7] Report:")
print(f"Accuracy drop: {fp32_top1 - int8_top1:.3f}")
print(f"Model compression rate: {fp32_model_size / int8_model_size:.3f}")
# https://docs.openvino.ai/latest/openvino_docs_optimization_guide_dldt_optimization_guide.html
print(f"Performance speed up (throughput mode): {int8_fps / fp32_fps:.3f}")
# Out:
# WARNING:nncf:NNCF provides best results with tensorflow==2.12.*, while current tensorflow version is 2.14.0. If you encounter issues, consider switching to tensorflow==2.12.*
# INFO:nncf:Creating compression algorithm: quantization
# INFO:nncf:Overflow issue fix was applied to first convolution weight quantizers.
# INFO:nncf:Collecting tensor statistics/data |█████           | 1 / 3
# INFO:nncf:Collecting tensor statistics/data |██████████      | 2 / 3
# INFO:nncf:Collecting tensor statistics/data |████████████████| 3 / 3
# INFO:nncf:BatchNorm statistics adaptation |█████           | 1 / 3
# INFO:nncf:BatchNorm statistics adaptation |██████████      | 2 / 3
# INFO:nncf:BatchNorm statistics adaptation |████████████████| 3 / 3
# [1/7] Save FP32 model: /content/drive/MyDrive/mobilenet_v2_fp32.xml
# Model graph (xml):   0.079 Mb
# Model weights (bin): 8.397 Mb
# Model size:          8.476 Mb
# [2/7] Save INT8 model: /content/drive/MyDrive/mobilenet_v2_int8.xml
# Model graph (xml):   0.397 Mb
# Model weights (bin): 2.242 Mb
# Model size:          2.639 Mb
# [3/7] Benchmark FP32 model:
# [ INFO ] Count:            1452 iterations
# [ INFO ] Duration:         15035.20 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        18.21 ms
# [ INFO ]    Average:       20.56 ms
# [ INFO ]    Min:           15.30 ms
# [ INFO ]    Max:           73.92 ms
# [ INFO ] Throughput:   96.57 FPS
# [4/7] Benchmark INT8 model:
# [ INFO ] Count:            1658 iterations
# [ INFO ] Duration:         15021.52 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        15.84 ms
# [ INFO ]    Average:       17.97 ms
# [ INFO ]    Min:           14.37 ms
# [ INFO ]    Max:           52.94 ms
# [ INFO ] Throughput:   110.37 FPS
# [5/7] Validate OpenVINO FP32 model:
# 100%|██████████| 31/31 [01:21<00:00,  2.65s/it]
# Accuracy @ top1: 0.198
# [6/7] Validate OpenVINO INT8 model:
# 100%|██████████| 31/31 [01:21<00:00,  2.64s/it]
# Accuracy @ top1: 0.198
# [7/7] Report:
# Accuracy drop: 0.000
# Model compression rate: 3.211
# Performance speed up (throughput mode): 1.143
# INFO:nncf:Creating compression algorithm: quantization
# INFO:nncf:Overflow issue fix was applied to first convolution weight quantizers.
# INFO:nncf:Collecting tensor statistics/data |█████           | 1 / 3
# INFO:nncf:Collecting tensor statistics/data |██████████      | 2 / 3
# INFO:nncf:Collecting tensor statistics/data |████████████████| 3 / 3
# INFO:nncf:BatchNorm statistics adaptation |█████           | 1 / 3
# INFO:nncf:BatchNorm statistics adaptation |██████████      | 2 / 3
# INFO:nncf:BatchNorm statistics adaptation |████████████████| 3 / 3
# [1/7] Save FP32 model: /content/drive/MyDrive/mobilenet_v2_fp32.xml
# Model graph (xml):   0.079 Mb
# Model weights (bin): 8.397 Mb
# Model size:          8.476 Mb
# [2/7] Save INT8 model: /content/drive/MyDrive/mobilenet_v2_int8.xml
# Model graph (xml):   0.397 Mb
# Model weights (bin): 2.242 Mb
# Model size:          2.639 Mb
# [3/7] Benchmark FP32 model:
# [ INFO ] Count:            1302 iterations
# [ INFO ] Duration:         15035.50 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        18.28 ms
# [ INFO ]    Average:       22.91 ms
# [ INFO ]    Min:           12.46 ms
# [ INFO ]    Max:           70.82 ms
# [ INFO ] Throughput:   86.60 FPS
# [4/7] Benchmark INT8 model:
# [ INFO ] Count:            1632 iterations
# [ INFO ] Duration:         15040.77 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        16.01 ms
# [ INFO ]    Average:       18.28 ms
# [ INFO ]    Min:           13.75 ms
# [ INFO ]    Max:           52.38 ms
# [ INFO ] Throughput:   108.51 FPS
# [5/7] Validate OpenVINO FP32 model:
# 100%|██████████| 31/31 [01:22<00:00,  2.65s/it]
# Accuracy @ top1: 0.198
# [6/7] Validate OpenVINO INT8 model:
# 100%|██████████| 31/31 [00:53<00:00,  1.72s/it]
# Accuracy @ top1: 0.198
# [7/7] Report:
# Accuracy drop: 0.000
# Model compression rate: 3.211
# Performance speed up (throughput mode): 1.253

# %%
|
