# %% [markdown]
# 우선 코드적으로 SEGEMENTATION이 가능한지 찾아보자. 그루터기의 경우 이부문이 가장

# %% [markdown]
# # 0. 라이브러리 임포트

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from google.colab import drive
from tensorflow.keras.applications import MobileNet
import re
import subprocess
from pathlib import Path
from typing import List, Optional
import tensorflow as tf
import tensorflow_datasets as tfds
from tqdm import tqdm

# %% [markdown]
# # 1. 데이터 로딩
#  - Convert color BGR to YUV
#  - Labeling

# %%
# 코랩 파일 마운트
drive.mount('/content/drive')

def loadfile(path):
    X = []
    Y = []

    for label in ('danger_key', 'danger', 'danger_st', 'danger_wi','normal' ,'warnning_both','warnning_leaf','warnning_sq') :
        print("Loading training images for the label: " + label)

        for filename in os.listdir(path + label + "/"):
            img = cv2.imread(path + label + "/" + filename)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
            img[:,:,0] = cv2.equalizeHist(img[:,:,0])
            img = cv2.cvtColor(img, cv2.COLOR_YUV2BGR)
            img = cv2.resize(img, (224, 224))
            X.append(img)
            if label == 'danger':
                Y.append(0)
            elif label == 'danger_key':
                Y.append(1)
            elif label == 'danger_st':
                Y.append(2)
            elif label == 'danger_wi':
                Y.append(3)
            elif label == 'normal':
                Y.append(4)
            elif label == 'warnning_sq':
                Y.append(5)
            elif label == 'warnning_leaf':
                Y.append(6)
            elif label == 'warnning_both':
                Y.append(7)


    X = np.array(X)
    Y = np.array(Y)

    return X, Y
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2. 데이터 전처리
# - Train, Validation Split
#  - Split rate - Train : Validation = 7:3
# - Data Augmentation
#  - 회전범위 증가, 전단 변환 추가, 줌 추가

# %%
# 데이터 불러오기
X, y = loadfile('/content/drive/MyDrive/data/')

# Train : Val = 0.7 : 0.3로 데이터 세트 분리
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# 정규화
X_train = X_train.astype('float32') / 255
X_val = X_val.astype('float32') / 255

# 데이터 증강
# 회전범위 증가(20-40),전단변화 추가, 줌 추가
datagen = ImageDataGenerator(
    rotation_range=180,  # 회전 범위 증가
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.3,  # 전단 변환 추가
    zoom_range=0.3,  # 줌 추가
    horizontal_flip=True,
    fill_mode='nearest'  # 새로 생성된 픽셀을 채우는 방법
)

# Compute quantities required for featurewise normalization
datagen.fit(X_train)
# Out:
# Loading training images for the label: danger_key
# Loading training images for the label: danger
# Loading training images for the label: danger_st
# Loading training images for the label: danger_wi
# Loading training images for the label: normal
# Loading training images for the label: warnning_both
# Loading training images for the label: warnning_leaf
# Loading training images for the label: warnning_sq

# %% [markdown]
# - 전처리 된 이미지 확인

# %%
# 전처리 된 후 이미지 샘플 랜덤으로 10장 확인

import random
import matplotlib.pyplot as plt

sample_images = random.sample(range(len(X_train)), 10)

plt.figure(figsize=(15, 5))
for i, idx in enumerate(sample_images):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[idx])
    plt.title(f"Label: {y_train[idx]}")
    plt.axis('off')
plt.show()

# %% [markdown]
# # 3. MobilenetV2 Modeling

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense

# Build model
model = Sequential()
model.add(MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights='imagenet'))  # Use MobileNet
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))  # Increase dropout
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(8, activation='softmax')) # Class 조정 3 -> 8

# 모델 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 128)               163968
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 2423496 (9.24 MB)
# Trainable params: 2389128 (9.11 MB)
# Non-trainable params: 34368 (134.25 KB)
# _________________________________________________________________

# %%
# 모델 저장코드
# model.save('/content/drive/MyDrive/240109_1600.h5')
# tf.saved_model.save(model, '240109_1600')

# %% [markdown]
# # 조기종료 콜백함수 설정
#  - Val_loss, Val_Accuracy 개선되지 않을 시 조기종료 활성화, 단 90번

# %%
from tensorflow.keras.callbacks import Callback

class CustomEarlyStopping(Callback):
    def __init__(self, patience=0):
        super(CustomEarlyStopping, self).__init__()
        self.patience = patience
        # 조기 종료를 위한 카운터
        self.best_weights = None  # 최고 성능의 가중치 저장

    def on_train_begin(self, logs=None):
        # 최소 손실을 추적
        self.best = np.Inf
        self.wait = 0  # 현재 대기 시간

    def on_epoch_end(self, epoch, logs=None):
        current_loss = logs.get('val_loss')
        current_accuracy = logs.get('val_accuracy')
        # 조건에 따른 조기 종료 검사
        if np.less(current_loss, self.best) and np.greater(current_accuracy, 0.90):  # 예를 들어 정확도 90% 이상
            self.best = current_loss
            self.wait = 0
            self.best_weights = self.model.get_weights()
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.model.stop_training = True
                print(f'조기 종료됨: epoch {epoch}')
                # 최고 성능 가중치로 모델 복원
                self.model.set_weights(self.best_weights)

# 콜백 인스턴스 생성
custom_early_stopping = CustomEarlyStopping(patience=100)

# %% [markdown]
# # 4. Train

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# 모델 체크포인트 콜백 설정
checkpoint = ModelCheckpoint(
    'mobilenetv2_tree_2nd.h5',  # 저장될 파일 이름
    monitor='val_loss',           # 모니터링할 값
    save_best_only=True,          # 가장 좋은 모델만 저장
    verbose=1                     # 진행 상황을 출력
)

# 모델 훈련
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=4),
    steps_per_epoch=len(X_train) / 4,
    epochs=100,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint, custom_early_stopping]  # 콜백 추가
)
# Out:
# Epoch 1/100
# 149/149 [============================>.] - ETA: 0s - loss: 2.2850 - accuracy: 0.1950
# Epoch 1: val_loss improved from inf to 4.15124, saving model to mobilenetv2_tree_2nd.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 149/149 [==============================] - 49s 106ms/step - loss: 2.2841 - accuracy: 0.1953 - val_loss: 4.1512 - val_accuracy: 0.3372
# Epoch 2/100
# 150/149 [==============================] - ETA: 0s - loss: 1.8351 - accuracy: 0.3022
# Epoch 2: val_loss improved from 4.15124 to 2.04207, saving model to mobilenetv2_tree_2nd.h5
# 149/149 [==============================] - 11s 72ms/step - loss: 1.8351 - accuracy: 0.3022 - val_loss: 2.0421 - val_accuracy: 0.3721
# Epoch 3/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7953 - accuracy: 0.2838
# Epoch 3: val_loss did not improve from 2.04207
# 149/149 [==============================] - 10s 68ms/step - loss: 1.7953 - accuracy: 0.2838 - val_loss: 2.7901 - val_accuracy: 0.2558
# Epoch 4/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7317 - accuracy: 0.3038
# Epoch 4: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 77ms/step - loss: 1.7317 - accuracy: 0.3038 - val_loss: 3.1792 - val_accuracy: 0.3372
# Epoch 5/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7328 - accuracy: 0.3022
# Epoch 5: val_loss did not improve from 2.04207
# 149/149 [==============================] - 13s 88ms/step - loss: 1.7328 - accuracy: 0.3022 - val_loss: 4.4118 - val_accuracy: 0.3411
# Epoch 6/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7307 - accuracy: 0.3055
# Epoch 6: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 72ms/step - loss: 1.7307 - accuracy: 0.3055 - val_loss: 3.8435 - val_accuracy: 0.1899
# Epoch 7/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7167 - accuracy: 0.2938
# Epoch 7: val_loss did not improve from 2.04207
# 149/149 [==============================] - 10s 65ms/step - loss: 1.7167 - accuracy: 0.2938 - val_loss: 13.5432 - val_accuracy: 0.0155
# Epoch 8/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.7740 - accuracy: 0.2706
# Epoch 8: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 76ms/step - loss: 1.7720 - accuracy: 0.2705 - val_loss: 5.1124 - val_accuracy: 0.2791
# Epoch 9/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7673 - accuracy: 0.2705
# Epoch 9: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 77ms/step - loss: 1.7673 - accuracy: 0.2705 - val_loss: 3.7311 - val_accuracy: 0.2016
# Epoch 10/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7475 - accuracy: 0.2654
# Epoch 10: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 74ms/step - loss: 1.7475 - accuracy: 0.2654 - val_loss: 2.9341 - val_accuracy: 0.2326
# Epoch 11/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7224 - accuracy: 0.3072
# Epoch 11: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 76ms/step - loss: 1.7224 - accuracy: 0.3072 - val_loss: 2.7298 - val_accuracy: 0.1667
# Epoch 12/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7345 - accuracy: 0.3038
# Epoch 12: val_loss did not improve from 2.04207
# 149/149 [==============================] - 9s 63ms/step - loss: 1.7345 - accuracy: 0.3038 - val_loss: 2.1784 - val_accuracy: 0.3140
# Epoch 13/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7084 - accuracy: 0.3406
# Epoch 13: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 73ms/step - loss: 1.7084 - accuracy: 0.3406 - val_loss: 2.6738 - val_accuracy: 0.2442
# Epoch 14/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.7322 - accuracy: 0.3143
# Epoch 14: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 78ms/step - loss: 1.7297 - accuracy: 0.3139 - val_loss: 7.3224 - val_accuracy: 0.0426
# Epoch 15/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7022 - accuracy: 0.3088
# Epoch 15: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 79ms/step - loss: 1.7022 - accuracy: 0.3088 - val_loss: 10.8835 - val_accuracy: 0.0271
# Epoch 16/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6885 - accuracy: 0.3155
# Epoch 16: val_loss did not improve from 2.04207
# 149/149 [==============================] - 9s 62ms/step - loss: 1.6885 - accuracy: 0.3155 - val_loss: 5.0001 - val_accuracy: 0.2481
# Epoch 17/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7045 - accuracy: 0.3289
# Epoch 17: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 73ms/step - loss: 1.7045 - accuracy: 0.3289 - val_loss: 3.6022 - val_accuracy: 0.1744
# Epoch 18/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6956 - accuracy: 0.3472
# Epoch 18: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 77ms/step - loss: 1.6956 - accuracy: 0.3472 - val_loss: 3.7849 - val_accuracy: 0.1899
# Epoch 19/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6662 - accuracy: 0.3222
# Epoch 19: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 80ms/step - loss: 1.6662 - accuracy: 0.3222 - val_loss: 4.0511 - val_accuracy: 0.2481
# Epoch 20/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7236 - accuracy: 0.3088
# Epoch 20: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 77ms/step - loss: 1.7236 - accuracy: 0.3088 - val_loss: 3.5794 - val_accuracy: 0.0814
# Epoch 21/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6973 - accuracy: 0.3573
# Epoch 21: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 71ms/step - loss: 1.6973 - accuracy: 0.3573 - val_loss: 10.5793 - val_accuracy: 0.0194
# Epoch 22/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6676 - accuracy: 0.3193
# Epoch 22: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 80ms/step - loss: 1.6679 - accuracy: 0.3189 - val_loss: 3.0109 - val_accuracy: 0.1395
# Epoch 23/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.7025 - accuracy: 0.3059
# Epoch 23: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 76ms/step - loss: 1.7016 - accuracy: 0.3072 - val_loss: 4.0632 - val_accuracy: 0.0504
# Epoch 24/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.7373 - accuracy: 0.2824
# Epoch 24: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 74ms/step - loss: 1.7402 - accuracy: 0.2805 - val_loss: 2.0496 - val_accuracy: 0.2868
# Epoch 25/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6835 - accuracy: 0.3155
# Epoch 25: val_loss did not improve from 2.04207
# 149/149 [==============================] - 10s 63ms/step - loss: 1.6835 - accuracy: 0.3155 - val_loss: 13.0908 - val_accuracy: 0.0194
# Epoch 26/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7381 - accuracy: 0.2938
# Epoch 26: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 79ms/step - loss: 1.7381 - accuracy: 0.2938 - val_loss: 2.2216 - val_accuracy: 0.2481
# Epoch 27/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6793 - accuracy: 0.3529
# Epoch 27: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 79ms/step - loss: 1.6784 - accuracy: 0.3523 - val_loss: 2.7172 - val_accuracy: 0.0659
# Epoch 28/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6554 - accuracy: 0.3439
# Epoch 28: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 76ms/step - loss: 1.6554 - accuracy: 0.3439 - val_loss: 2.7395 - val_accuracy: 0.2093
# Epoch 29/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6899 - accuracy: 0.3172
# Epoch 29: val_loss did not improve from 2.04207
# 149/149 [==============================] - 9s 62ms/step - loss: 1.6899 - accuracy: 0.3172 - val_loss: 2.9501 - val_accuracy: 0.0659
# Epoch 30/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6742 - accuracy: 0.3573
# Epoch 30: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 80ms/step - loss: 1.6742 - accuracy: 0.3573 - val_loss: 6.6063 - val_accuracy: 0.0310
# Epoch 31/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6628 - accuracy: 0.3406
# Epoch 31: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 79ms/step - loss: 1.6628 - accuracy: 0.3406 - val_loss: 3.9674 - val_accuracy: 0.1008
# Epoch 32/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6747 - accuracy: 0.3322
# Epoch 32: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 70ms/step - loss: 1.6747 - accuracy: 0.3322 - val_loss: 14.4831 - val_accuracy: 0.0194
# Epoch 33/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6716 - accuracy: 0.3189
# Epoch 33: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 80ms/step - loss: 1.6716 - accuracy: 0.3189 - val_loss: 8.1999 - val_accuracy: 0.0233
# Epoch 34/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6524 - accuracy: 0.3272
# Epoch 34: val_loss did not improve from 2.04207
# 149/149 [==============================] - 10s 69ms/step - loss: 1.6524 - accuracy: 0.3272 - val_loss: 3.7023 - val_accuracy: 0.0736
# Epoch 35/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6261 - accuracy: 0.3322
# Epoch 35: val_loss did not improve from 2.04207
# 149/149 [==============================] - 10s 69ms/step - loss: 1.6261 - accuracy: 0.3322 - val_loss: 3.5830 - val_accuracy: 0.1279
# Epoch 36/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6766 - accuracy: 0.3356
# Epoch 36: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 77ms/step - loss: 1.6766 - accuracy: 0.3356 - val_loss: 8.8727 - val_accuracy: 0.0194
# Epoch 37/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6832 - accuracy: 0.3372
# Epoch 37: val_loss did not improve from 2.04207
# 149/149 [==============================] - 9s 61ms/step - loss: 1.6832 - accuracy: 0.3372 - val_loss: 8.0805 - val_accuracy: 0.0233
# Epoch 38/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6721 - accuracy: 0.3529
# Epoch 38: val_loss did not improve from 2.04207
# 149/149 [==============================] - 10s 69ms/step - loss: 1.6738 - accuracy: 0.3539 - val_loss: 5.5519 - val_accuracy: 0.0233
# Epoch 39/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6446 - accuracy: 0.3472
# Epoch 39: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 77ms/step - loss: 1.6446 - accuracy: 0.3472 - val_loss: 11.3938 - val_accuracy: 0.0194
# Epoch 40/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6349 - accuracy: 0.3378
# Epoch 40: val_loss did not improve from 2.04207
# 149/149 [==============================] - 10s 64ms/step - loss: 1.6374 - accuracy: 0.3389 - val_loss: 3.7921 - val_accuracy: 0.2946
# Epoch 41/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6822 - accuracy: 0.3092
# Epoch 41: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 75ms/step - loss: 1.6808 - accuracy: 0.3088 - val_loss: 2.9054 - val_accuracy: 0.3372
# Epoch 42/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6543 - accuracy: 0.3038
# Epoch 42: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 76ms/step - loss: 1.6543 - accuracy: 0.3038 - val_loss: 10.1680 - val_accuracy: 0.0349
# Epoch 43/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6689 - accuracy: 0.3429
# Epoch 43: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 77ms/step - loss: 1.6713 - accuracy: 0.3422 - val_loss: 2.0780 - val_accuracy: 0.2093
# Epoch 44/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6414 - accuracy: 0.3573
# Epoch 44: val_loss did not improve from 2.04207
# 149/149 [==============================] - 12s 79ms/step - loss: 1.6414 - accuracy: 0.3573 - val_loss: 3.9160 - val_accuracy: 0.0426
# Epoch 45/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6344 - accuracy: 0.3573
# Epoch 45: val_loss did not improve from 2.04207
# 149/149 [==============================] - 11s 71ms/step - loss: 1.6344 - accuracy: 0.3573 - val_loss: 2.5190 - val_accuracy: 0.1822
# Epoch 46/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6524 - accuracy: 0.3773
# Epoch 46: val_loss improved from 2.04207 to 2.02413, saving model to mobilenetv2_tree_2nd.h5
# 149/149 [==============================] - 12s 80ms/step - loss: 1.6524 - accuracy: 0.3773 - val_loss: 2.0241 - val_accuracy: 0.3876
# Epoch 47/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6114 - accuracy: 0.3840
# Epoch 47: val_loss did not improve from 2.02413
# 149/149 [==============================] - 11s 76ms/step - loss: 1.6114 - accuracy: 0.3840 - val_loss: 5.6097 - val_accuracy: 0.0659
# Epoch 48/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6259 - accuracy: 0.3731
# Epoch 48: val_loss did not improve from 2.02413
# 149/149 [==============================] - 12s 76ms/step - loss: 1.6290 - accuracy: 0.3723 - val_loss: 4.1809 - val_accuracy: 0.0271
# Epoch 49/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6649 - accuracy: 0.3606
# Epoch 49: val_loss did not improve from 2.02413
# 149/149 [==============================] - 12s 77ms/step - loss: 1.6649 - accuracy: 0.3606 - val_loss: 13.4047 - val_accuracy: 0.0194
# Epoch 50/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7645 - accuracy: 0.2922
# Epoch 50: val_loss did not improve from 2.02413
# 149/149 [==============================] - 11s 73ms/step - loss: 1.7645 - accuracy: 0.2922 - val_loss: 11.2376 - val_accuracy: 0.0194
# Epoch 51/100
# 150/149 [==============================] - ETA: 0s - loss: 1.7005 - accuracy: 0.3189
# Epoch 51: val_loss improved from 2.02413 to 1.77487, saving model to mobilenetv2_tree_2nd.h5
# 149/149 [==============================] - 12s 83ms/step - loss: 1.7005 - accuracy: 0.3189 - val_loss: 1.7749 - val_accuracy: 0.2442
# Epoch 52/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6922 - accuracy: 0.3139
# Epoch 52: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 79ms/step - loss: 1.6922 - accuracy: 0.3139 - val_loss: 3.9132 - val_accuracy: 0.0194
# Epoch 53/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6820 - accuracy: 0.3172
# Epoch 53: val_loss did not improve from 1.77487
# 149/149 [==============================] - 11s 70ms/step - loss: 1.6820 - accuracy: 0.3172 - val_loss: 5.3726 - val_accuracy: 0.0155
# Epoch 54/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6828 - accuracy: 0.3406
# Epoch 54: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 78ms/step - loss: 1.6828 - accuracy: 0.3406 - val_loss: 9.3292 - val_accuracy: 0.0194
# Epoch 55/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6497 - accuracy: 0.3406
# Epoch 55: val_loss did not improve from 1.77487
# 149/149 [==============================] - 11s 76ms/step - loss: 1.6497 - accuracy: 0.3406 - val_loss: 6.0409 - val_accuracy: 0.0194
# Epoch 56/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6663 - accuracy: 0.3239
# Epoch 56: val_loss did not improve from 1.77487
# 149/149 [==============================] - 10s 67ms/step - loss: 1.6663 - accuracy: 0.3239 - val_loss: 10.3411 - val_accuracy: 0.0194
# Epoch 57/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6626 - accuracy: 0.3356
# Epoch 57: val_loss did not improve from 1.77487
# 149/149 [==============================] - 11s 70ms/step - loss: 1.6626 - accuracy: 0.3356 - val_loss: 2.5626 - val_accuracy: 0.1434
# Epoch 58/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6796 - accuracy: 0.3356
# Epoch 58: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 78ms/step - loss: 1.6796 - accuracy: 0.3356 - val_loss: 5.4283 - val_accuracy: 0.0194
# Epoch 59/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6506 - accuracy: 0.3356
# Epoch 59: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 78ms/step - loss: 1.6506 - accuracy: 0.3356 - val_loss: 14.4749 - val_accuracy: 0.0194
# Epoch 60/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6791 - accuracy: 0.3506
# Epoch 60: val_loss did not improve from 1.77487
# 149/149 [==============================] - 9s 63ms/step - loss: 1.6791 - accuracy: 0.3506 - val_loss: 10.2378 - val_accuracy: 0.0194
# Epoch 61/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6566 - accuracy: 0.3289
# Epoch 61: val_loss did not improve from 1.77487
# 149/149 [==============================] - 11s 70ms/step - loss: 1.6566 - accuracy: 0.3289 - val_loss: 6.3068 - val_accuracy: 0.0194
# Epoch 62/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6523 - accuracy: 0.3445
# Epoch 62: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 77ms/step - loss: 1.6535 - accuracy: 0.3439 - val_loss: 6.1405 - val_accuracy: 0.0194
# Epoch 63/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6396 - accuracy: 0.3496
# Epoch 63: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 78ms/step - loss: 1.6399 - accuracy: 0.3506 - val_loss: 5.8364 - val_accuracy: 0.0194
# Epoch 64/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6588 - accuracy: 0.3556
# Epoch 64: val_loss did not improve from 1.77487
# 149/149 [==============================] - 13s 89ms/step - loss: 1.6588 - accuracy: 0.3556 - val_loss: 2.3224 - val_accuracy: 0.1938
# Epoch 65/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6406 - accuracy: 0.3422
# Epoch 65: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 78ms/step - loss: 1.6406 - accuracy: 0.3422 - val_loss: 6.3432 - val_accuracy: 0.0310
# Epoch 66/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6859 - accuracy: 0.3172
# Epoch 66: val_loss did not improve from 1.77487
# 149/149 [==============================] - 10s 69ms/step - loss: 1.6859 - accuracy: 0.3172 - val_loss: 4.7846 - val_accuracy: 0.0388
# Epoch 67/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6786 - accuracy: 0.3239
# Epoch 67: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 79ms/step - loss: 1.6786 - accuracy: 0.3239 - val_loss: 5.0646 - val_accuracy: 0.0736
# Epoch 68/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6512 - accuracy: 0.3193
# Epoch 68: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 79ms/step - loss: 1.6546 - accuracy: 0.3189 - val_loss: 3.3598 - val_accuracy: 0.1395
# Epoch 69/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6877 - accuracy: 0.3222
# Epoch 69: val_loss did not improve from 1.77487
# 149/149 [==============================] - 11s 71ms/step - loss: 1.6877 - accuracy: 0.3222 - val_loss: 2.6326 - val_accuracy: 0.2481
# Epoch 70/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6658 - accuracy: 0.3339
# Epoch 70: val_loss did not improve from 1.77487
# 149/149 [==============================] - 12s 77ms/step - loss: 1.6658 - accuracy: 0.3339 - val_loss: 3.2497 - val_accuracy: 0.2481
# Epoch 71/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6790 - accuracy: 0.3172
# Epoch 71: val_loss did not improve from 1.77487
# 149/149 [==============================] - 10s 66ms/step - loss: 1.6790 - accuracy: 0.3172 - val_loss: 2.5037 - val_accuracy: 0.2442
# Epoch 72/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6449 - accuracy: 0.3412
# Epoch 72: val_loss did not improve from 1.77487
# 149/149 [==============================] - 11s 70ms/step - loss: 1.6435 - accuracy: 0.3422 - val_loss: 1.8653 - val_accuracy: 0.2364
# Epoch 73/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6547 - accuracy: 0.3412
# Epoch 73: val_loss improved from 1.77487 to 1.72228, saving model to mobilenetv2_tree_2nd.h5
# 149/149 [==============================] - 12s 82ms/step - loss: 1.6549 - accuracy: 0.3422 - val_loss: 1.7223 - val_accuracy: 0.3256
# Epoch 74/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6274 - accuracy: 0.3656
# Epoch 74: val_loss did not improve from 1.72228
# 149/149 [==============================] - 12s 77ms/step - loss: 1.6274 - accuracy: 0.3656 - val_loss: 2.1345 - val_accuracy: 0.2752
# Epoch 75/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6620 - accuracy: 0.3205
# Epoch 75: val_loss did not improve from 1.72228
# 149/149 [==============================] - 16s 105ms/step - loss: 1.6620 - accuracy: 0.3205 - val_loss: 2.3428 - val_accuracy: 0.1667
# Epoch 76/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6648 - accuracy: 0.3239
# Epoch 76: val_loss did not improve from 1.72228
# 149/149 [==============================] - 11s 71ms/step - loss: 1.6648 - accuracy: 0.3239 - val_loss: 2.4343 - val_accuracy: 0.2713
# Epoch 77/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6616 - accuracy: 0.3445
# Epoch 77: val_loss did not improve from 1.72228
# 149/149 [==============================] - 12s 77ms/step - loss: 1.6651 - accuracy: 0.3439 - val_loss: 3.1105 - val_accuracy: 0.0504
# Epoch 78/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6446 - accuracy: 0.3456
# Epoch 78: val_loss improved from 1.72228 to 1.65855, saving model to mobilenetv2_tree_2nd.h5
# 149/149 [==============================] - 10s 69ms/step - loss: 1.6446 - accuracy: 0.3456 - val_loss: 1.6586 - val_accuracy: 0.3411
# Epoch 79/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6137 - accuracy: 0.3856
# Epoch 79: val_loss did not improve from 1.65855
# 149/149 [==============================] - 11s 72ms/step - loss: 1.6137 - accuracy: 0.3856 - val_loss: 2.0634 - val_accuracy: 0.1977
# Epoch 80/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6390 - accuracy: 0.3506
# Epoch 80: val_loss did not improve from 1.65855
# 149/149 [==============================] - 12s 78ms/step - loss: 1.6390 - accuracy: 0.3506 - val_loss: 2.9237 - val_accuracy: 0.1550
# Epoch 81/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6382 - accuracy: 0.3656
# Epoch 81: val_loss did not improve from 1.65855
# 149/149 [==============================] - 12s 79ms/step - loss: 1.6382 - accuracy: 0.3656 - val_loss: 1.7578 - val_accuracy: 0.2829
# Epoch 82/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6075 - accuracy: 0.3706
# Epoch 82: val_loss did not improve from 1.65855
# 149/149 [==============================] - 10s 64ms/step - loss: 1.6075 - accuracy: 0.3706 - val_loss: 2.1510 - val_accuracy: 0.2907
# Epoch 83/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6011 - accuracy: 0.3664
# Epoch 83: val_loss did not improve from 1.65855
# 149/149 [==============================] - 11s 72ms/step - loss: 1.6019 - accuracy: 0.3656 - val_loss: 2.0696 - val_accuracy: 0.2403
# Epoch 84/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6410 - accuracy: 0.3456
# Epoch 84: val_loss did not improve from 1.65855
# 149/149 [==============================] - 14s 96ms/step - loss: 1.6410 - accuracy: 0.3456 - val_loss: 1.7571 - val_accuracy: 0.2519
# Epoch 85/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6068 - accuracy: 0.3589
# Epoch 85: val_loss did not improve from 1.65855
# 149/149 [==============================] - 11s 77ms/step - loss: 1.6068 - accuracy: 0.3589 - val_loss: 1.7232 - val_accuracy: 0.2442
# Epoch 86/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6275 - accuracy: 0.3606
# Epoch 86: val_loss did not improve from 1.65855
# 149/149 [==============================] - 10s 67ms/step - loss: 1.6275 - accuracy: 0.3606 - val_loss: 1.6929 - val_accuracy: 0.2403
# Epoch 87/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6716 - accuracy: 0.3239
# Epoch 87: val_loss did not improve from 1.65855
# 149/149 [==============================] - 10s 68ms/step - loss: 1.6716 - accuracy: 0.3239 - val_loss: 1.8730 - val_accuracy: 0.2752
# Epoch 88/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6649 - accuracy: 0.3523
# Epoch 88: val_loss improved from 1.65855 to 1.64552, saving model to mobilenetv2_tree_2nd.h5
# 149/149 [==============================] - 12s 82ms/step - loss: 1.6649 - accuracy: 0.3523 - val_loss: 1.6455 - val_accuracy: 0.3450
# Epoch 89/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6527 - accuracy: 0.3356
# Epoch 89: val_loss did not improve from 1.64552
# 149/149 [==============================] - 12s 80ms/step - loss: 1.6527 - accuracy: 0.3356 - val_loss: 2.0767 - val_accuracy: 0.2481
# Epoch 90/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6283 - accuracy: 0.3623
# Epoch 90: val_loss did not improve from 1.64552
# 149/149 [==============================] - 11s 70ms/step - loss: 1.6283 - accuracy: 0.3623 - val_loss: 1.9372 - val_accuracy: 0.3333
# Epoch 91/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6199 - accuracy: 0.3773
# Epoch 91: val_loss did not improve from 1.64552
# 149/149 [==============================] - 11s 73ms/step - loss: 1.6199 - accuracy: 0.3773 - val_loss: 4.8320 - val_accuracy: 0.0465
# Epoch 92/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6314 - accuracy: 0.3573
# Epoch 92: val_loss did not improve from 1.64552
# 149/149 [==============================] - 12s 83ms/step - loss: 1.6314 - accuracy: 0.3573 - val_loss: 6.4487 - val_accuracy: 0.0465
# Epoch 93/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6131 - accuracy: 0.3606
# Epoch 93: val_loss did not improve from 1.64552
# 149/149 [==============================] - 12s 79ms/step - loss: 1.6131 - accuracy: 0.3606 - val_loss: 2.1213 - val_accuracy: 0.2984
# Epoch 94/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6154 - accuracy: 0.3790
# Epoch 94: val_loss did not improve from 1.64552
# 149/149 [==============================] - 12s 80ms/step - loss: 1.6154 - accuracy: 0.3790 - val_loss: 2.2899 - val_accuracy: 0.2287
# Epoch 95/100
# 149/149 [============================>.] - ETA: 0s - loss: 1.6313 - accuracy: 0.3529
# Epoch 95: val_loss did not improve from 1.64552
# 149/149 [==============================] - 12s 83ms/step - loss: 1.6313 - accuracy: 0.3523 - val_loss: 2.9162 - val_accuracy: 0.1318
# Epoch 96/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6588 - accuracy: 0.3289
# Epoch 96: val_loss did not improve from 1.64552
# 149/149 [==============================] - 12s 82ms/step - loss: 1.6588 - accuracy: 0.3289 - val_loss: 3.4685 - val_accuracy: 0.0969
# Epoch 97/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6534 - accuracy: 0.3306
# Epoch 97: val_loss did not improve from 1.64552
# 149/149 [==============================] - 11s 72ms/step - loss: 1.6534 - accuracy: 0.3306 - val_loss: 4.5186 - val_accuracy: 0.0659
# Epoch 98/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6366 - accuracy: 0.3556
# Epoch 98: val_loss did not improve from 1.64552
# 149/149 [==============================] - 11s 71ms/step - loss: 1.6366 - accuracy: 0.3556 - val_loss: 6.0397 - val_accuracy: 0.0310
# Epoch 99/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6670 - accuracy: 0.3689
# Epoch 99: val_loss did not improve from 1.64552
# 149/149 [==============================] - 12s 82ms/step - loss: 1.6670 - accuracy: 0.3689 - val_loss: 9.5812 - val_accuracy: 0.0194
# Epoch 100/100
# 150/149 [==============================] - ETA: 0s - loss: 1.6175 - accuracy: 0.3723
# Epoch 100: val_loss did not improve from 1.64552
# 조기 종료됨: epoch 99
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-0d62745084a6> in <cell line: 12>()
#      10
#      11 # 모델 훈련
# ---> 12 history = model.fit(
#      13     datagen.flow(X_train, y_train, batch_size=4),
#      14     steps_per_epoch=len(X_train) / 4,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# <ipython-input-8-af680b894866> in on_epoch_end(self, epoch, logs)
#      27                 print(f'조기 종료됨: epoch {epoch}')
#      28                 # 최고 성능 가중치로 모델 복원
# ---> 29                 self.model.set_weights(self.best_weights)
#      30
#      31 # 콜백 인스턴스 생성
#
# TypeError: object of type 'NoneType' has no len()

# %%
# tf.saved_model.save(model,'231205_1430')

# %% [markdown]
# # 5. 평가

# %%
from tensorflow.keras.models import load_model

# 최고 성능 모델 불러오기
best_model = load_model('mobilenetv2_tree_2nd.h5')

# 훈련 데이터와 검증 데이터에 대한 성능 평가
train_loss, train_accuracy = best_model.evaluate(X_train, y_train, verbose=0)
val_loss, val_accuracy = best_model.evaluate(X_val, y_val, verbose=0)

# 성능 시각화
plt.figure(figsize=(12, 6))

# 정확도 그래프
plt.subplot(1, 2, 1)
plt.bar(['Train', 'Validation'], [train_accuracy, val_accuracy], color=['blue', 'orange'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')

# 손실 그래프
plt.subplot(1, 2, 2)
plt.bar(['Train', 'Validation'], [train_loss, val_loss], color=['blue', 'orange'])
plt.title('Model Loss')
plt.ylabel('Loss')

plt.show()

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
class_names = ['danger', 'danger_key', 'danger_st', 'danger_wi', 'normal', 'warnning_both', 'warnning_leaf', 'warnning_sq']

# 최고 성능 모델 불러오기
best_model = load_model('mobilenetv2_tree_2nd.h5')

# 검증 데이터에 대한 예측 수행
y_pred = best_model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)

# 혼동 행렬 생성
cm = confusion_matrix(y_val, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# 분류 보고서 생성
print(classification_report(y_val, y_pred_classes, target_names=class_names))
# Out:
# 9/9 [==============================] - 1s 45ms/step
#                precision    recall  f1-score   support
#
#        danger       0.29      0.09      0.14        64
#    danger_key       0.00      0.00      0.00         4
#     danger_st       0.00      0.00      0.00         5
#     danger_wi       0.12      0.20      0.15         5
#        normal       0.36      0.94      0.52        87
# warnning_both       0.00      0.00      0.00        36
# warnning_leaf       0.00      0.00      0.00        47
#   warnning_sq       0.00      0.00      0.00        10
#
#      accuracy                           0.34       258
#     macro avg       0.10      0.15      0.10       258
#  weighted avg       0.19      0.34      0.21       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# 평가 시간 측정 및 용량 확인

import time
import os

def get_model_inference_time_and_size(model):
    # 모델 저장
    model_path = 'mobilenetv2_tree_2nd.h5'
    model.save(model_path)

    # 모델 파일 크기 확인 (MB 단위)
    model_size = os.path.getsize(model_path) / (1024 * 1024)

    # 추론 시간 측정
    num_samples = 50
    sample_images = random.sample(range(len(X_train)), num_samples)
    start_time = time.time()
    for idx in sample_images:
        _ = model.predict(np.expand_dims(X_train[idx], axis=0))
    end_time = time.time()
    inference_time_per_image = (end_time - start_time) / num_samples

    return model_size, inference_time_per_image

model_size, inference_time = get_model_inference_time_and_size(model)
print(f"Model Size: {model_size:.2f} MB")
print(f"Inference Time per Image: {inference_time * 1000:.2f} ms")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Model Size: 28.14 MB
# Inference Time per Image: 123.72 ms

# %%
from tensorflow.keras.models import load_model
import random
import numpy as np
import matplotlib.pyplot as plt

class_names = ['danger', 'danger_key', 'danger_st', 'danger_wi', 'normal', 'warnning_both', 'warnning_leaf', 'warnning_sq']

# 저장된 최고 성능 모델 불러오기
best_model = load_model('mobilenetv2_tree_2nd.h5')

# 50장의 무작위 테스트 이미지 선택
sample_images = random.sample(range(len(X_val)), 50)

correct_count = 0  # 정확하게 분류된 이미지 수

# 추론 및 결과 표시
plt.figure(figsize=(15, 15))
for i, idx in enumerate(sample_images):
    image = X_val[idx]
    true_label = y_val[idx]

    # 이미지 추론
    predicted_probs = best_model.predict(np.expand_dims(image, axis=0))
    predicted_label = np.argmax(predicted_probs)

    # 이미지와 추론 결과 표시
    plt.subplot(10, 5, i + 1)
    plt.imshow(image)
    plt.axis('off')
    if true_label == predicted_label:
        plt.title(f"Label: {class_names[true_label]}\nCorrect", color='green')
        correct_count += 1
    else:
        plt.title(f"Label: {class_names[true_label]}\nPredicted: {class_names[predicted_label]}", color='red')

plt.tight_layout()
plt.show()

# 정확도 출력
accuracy = (correct_count / len(sample_images)) * 100
print(f"추론 정확도: {accuracy:.2f}%")
# Out:
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 추론 정확도: 0.00%

# %% [markdown]
# # 6. 최적화

# %%
import os
import re
import subprocess
from pathlib import Path
from typing import List, Optional
import openvino as ov
import tensorflow as tf
import tensorflow_datasets as tfds
from tqdm import tqdm
import nncf
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive')
#print('current:', os.getcwd())

ROOT = Path('/content/drive/MyDrive/mobilenetv2_tree_2nd').parent.resolve()
WEIGHTS_URL = "/content/drive/MyDrive/mobilenetv2_tree_2nd.h5"
DATASET_CLASSES = 8


def validate(model: ov.Model, val_loader: tf.data.Dataset) -> tf.Tensor:
    compiled_model = ov.compile_model(model)
    output = compiled_model.outputs[0]

    metric = tf.keras.metrics.CategoricalAccuracy(name="acc@1")
    for images, labels in tqdm(val_loader):
        pred = compiled_model(images.numpy())[output]
        metric.update_state(labels, pred)

    return metric.result()


def run_benchmark(model_path: str, shape: Optional[List[int]] = None, verbose: bool = True) -> float:
    command = f"benchmark_app -m {model_path} -d CPU -api async -t 15"
    if shape is not None:
        command += f' -shape [{",".join(str(x) for x in shape)}]'
    cmd_output = subprocess.check_output(command, shell=True)  # nosec
    if verbose:
        print(*str(cmd_output).split("\\n")[-9:-1], sep="\n")
    match = re.search(r"Throughput\: (.+?) FPS", str(cmd_output))
    return float(match.group(1))


def get_model_size(ir_path: str, m_type: str = "Mb", verbose: bool = True) -> float:
    xml_size = os.path.getsize(ir_path)
    bin_size = os.path.getsize(os.path.splitext(ir_path)[0] + ".bin")
    for t in ["bytes", "Kb", "Mb"]:
        if m_type == t:
            break
        xml_size /= 1024
        bin_size /= 1024
    model_size = xml_size + bin_size
    if verbose:
        print(f"Model graph (xml):   {xml_size:.3f} Mb")
        print(f"Model weights (bin): {bin_size:.3f} Mb")
        print(f"Model size:          {model_size:.3f} Mb")
    return model_size


###############################################################################
# Create a Tensorflow model and dataset


def center_crop(image: tf.Tensor, image_size: int, crop_padding: int) -> tf.Tensor:
    shape = tf.shape(image)
    image_height = shape[0]
    image_width = shape[1]

    padded_center_crop_size = tf.cast(
        ((image_size / (image_size + crop_padding)) * tf.cast(tf.minimum(image_height, image_width), tf.float32)),
        tf.int32,
    )

    offset_height = ((image_height - padded_center_crop_size) + 1) // 2
    offset_width = ((image_width - padded_center_crop_size) + 1) // 2

    image = tf.image.crop_to_bounding_box(
        image,
        offset_height=offset_height,
        offset_width=offset_width,
        target_height=padded_center_crop_size,
        target_width=padded_center_crop_size,
    )

    image = tf.compat.v1.image.resize(
        image, [image_size, image_size], method=tf.image.ResizeMethod.BILINEAR, align_corners=False
    )

    return image


def preprocess_for_eval(image, label):
    image = center_crop(image, 224, 32)
    image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
    image = tf.image.convert_image_dtype(image, tf.float32)

    label = tf.one_hot(label, DATASET_CLASSES)

    return image, label


val_dataset = tfds.load("imagenette/320px-v2", split="validation", shuffle_files=False, as_supervised=True)
val_dataset = val_dataset.map(preprocess_for_eval).batch(128)

weights_path = tf.keras.utils.get_file("/content/drive/MyDrive/mobilenetv2_tree_2nd", WEIGHTS_URL, cache_subdir="models")
tf_model = tf.keras.applications.MobileNetV2(weights=weights_path, classes=DATASET_CLASSES)

###############################################################################
# Quantize a Tensorflow model
#
# The transformation function transforms a data item into model input data.
#
# To validate the transform function use the following code:
# >> for data_item in val_loader:
# >>    model(transform_fn(data_item))


# def transform_fn(data_item):
#     images, _ = data_item
#     return images


# # The calibration dataset is a small, no label, representative dataset
# # (~100-500 samples) that is used to estimate the range, i.e. (min, max) of all
# # floating point activation tensors in the model, to initialize the quantization
# # parameters.
# #
# # The easiest way to define a calibration dataset is to use a training or
# # validation dataset and a transformation function to remove labels from the data
# # item and prepare model input data. The quantize method uses a small subset
# # (default: 300 samples) of the calibration dataset.

# calibration_dataset = nncf.Dataset(val_dataset, transform_fn)
# tf_quantized_model = nncf.quantize(tf_model, calibration_dataset)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Quantize a Tensorflow model
#
# The transformation function transforms a data item into model input data.
#
# To validate the transform function use the following code:
# >> for data_item in val_loader:
# >>    model(transform_fn(data_item))


def transform_fn(data_item):
    images, _ = data_item
    return images


# The calibration dataset is a small, no label, representative dataset
# (~100-500 samples) that is used to estimate the range, i.e. (min, max) of all
# floating point activation tensors in the model, to initialize the quantization
# parameters.
#
# The easiest way to define a calibration dataset is to use a training or
# validation dataset and a transformation function to remove labels from the data
# item and prepare model input data. The quantize method uses a small subset
# (default: 300 samples) of the calibration dataset.

calibration_dataset = nncf.Dataset(val_dataset, transform_fn)
tf_quantized_model = nncf.quantize(tf_model, calibration_dataset)

###############################################################################
# Benchmark performance, calculate compression rate and validate accuracy

ov_model = ov.convert_model(tf_model, share_weights=False)
#경량화 모델 : ov_quntized_model
ov_quantized_model = ov.convert_model(tf_quantized_model, share_weights=False)

fp32_ir_path = f"{ROOT}/mobilenet_v2_fp32.xml"
ov.save_model(ov_model, fp32_ir_path, compress_to_fp16=False)
print(f"[1/7] Save FP32 model: {fp32_ir_path}")
fp32_model_size = get_model_size(fp32_ir_path, verbose=True)

int8_ir_path = f"{ROOT}/mobilenet_v2_int8.xml"
ov.save_model(ov_quantized_model, int8_ir_path, compress_to_fp16=False)
print(f"[2/7] Save INT8 model: {int8_ir_path}")
int8_model_size = get_model_size(int8_ir_path, verbose=True)

print("[3/7] Benchmark FP32 model:")
fp32_fps = run_benchmark(fp32_ir_path, shape=[1, 224, 224, 3], verbose=True)
print("[4/7] Benchmark INT8 model:")
int8_fps = run_benchmark(int8_ir_path, shape=[1, 224, 224, 3], verbose=True)

print("[5/7] Validate OpenVINO FP32 model:")
fp32_top1 = validate(ov_model, val_dataset)
print(f"Accuracy @ top1: {fp32_top1:.3f}")

print("[6/7] Validate OpenVINO INT8 model:")
int8_top1 = validate(ov_quantized_model, val_dataset)
print(f"Accuracy @ top1: {int8_top1:.3f}")

print("[7/7] Report:")
print(f"Accuracy drop: {fp32_top1 - int8_top1:.3f}")
print(f"Model compression rate: {fp32_model_size / int8_model_size:.3f}")
# https://docs.openvino.ai/latest/openvino_docs_optimization_guide_dldt_optimization_guide.html
print(f"Performance speed up (throughput mode): {int8_fps / fp32_fps:.3f}")
# Out:
# WARNING:nncf:NNCF provides best results with tensorflow==2.12.*, while current tensorflow version is 2.14.0. If you encounter issues, consider switching to tensorflow==2.12.*
# INFO:nncf:Creating compression algorithm: quantization
# INFO:nncf:Overflow issue fix was applied to first convolution weight quantizers.
# INFO:nncf:Collecting tensor statistics/data |█████           | 1 / 3
# INFO:nncf:Collecting tensor statistics/data |██████████      | 2 / 3
# INFO:nncf:Collecting tensor statistics/data |████████████████| 3 / 3
# INFO:nncf:BatchNorm statistics adaptation |█████           | 1 / 3
# INFO:nncf:BatchNorm statistics adaptation |██████████      | 2 / 3
# INFO:nncf:BatchNorm statistics adaptation |████████████████| 3 / 3
# [1/7] Save FP32 model: /content/drive/MyDrive/mobilenet_v2_fp32.xml
# Model graph (xml):   0.079 Mb
# Model weights (bin): 8.397 Mb
# Model size:          8.476 Mb
# [2/7] Save INT8 model: /content/drive/MyDrive/mobilenet_v2_int8.xml
# Model graph (xml):   0.397 Mb
# Model weights (bin): 2.242 Mb
# Model size:          2.639 Mb
# [3/7] Benchmark FP32 model:
# [ INFO ] Count:            1452 iterations
# [ INFO ] Duration:         15035.20 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        18.21 ms
# [ INFO ]    Average:       20.56 ms
# [ INFO ]    Min:           15.30 ms
# [ INFO ]    Max:           73.92 ms
# [ INFO ] Throughput:   96.57 FPS
# [4/7] Benchmark INT8 model:
# [ INFO ] Count:            1658 iterations
# [ INFO ] Duration:         15021.52 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        15.84 ms
# [ INFO ]    Average:       17.97 ms
# [ INFO ]    Min:           14.37 ms
# [ INFO ]    Max:           52.94 ms
# [ INFO ] Throughput:   110.37 FPS
# [5/7] Validate OpenVINO FP32 model:
# 100%|██████████| 31/31 [01:21<00:00,  2.65s/it]
# Accuracy @ top1: 0.198
# [6/7] Validate OpenVINO INT8 model:
# 100%|██████████| 31/31 [01:21<00:00,  2.64s/it]
# Accuracy @ top1: 0.198
# [7/7] Report:
# Accuracy drop: 0.000
# Model compression rate: 3.211
# Performance speed up (throughput mode): 1.143
# INFO:nncf:Creating compression algorithm: quantization
# INFO:nncf:Overflow issue fix was applied to first convolution weight quantizers.
# INFO:nncf:Collecting tensor statistics/data |█████           | 1 / 3
# INFO:nncf:Collecting tensor statistics/data |██████████      | 2 / 3
# INFO:nncf:Collecting tensor statistics/data |████████████████| 3 / 3
# INFO:nncf:BatchNorm statistics adaptation |█████           | 1 / 3
# INFO:nncf:BatchNorm statistics adaptation |██████████      | 2 / 3
# INFO:nncf:BatchNorm statistics adaptation |████████████████| 3 / 3
# [1/7] Save FP32 model: /content/drive/MyDrive/mobilenet_v2_fp32.xml
# Model graph (xml):   0.079 Mb
# Model weights (bin): 8.397 Mb
# Model size:          8.476 Mb
# [2/7] Save INT8 model: /content/drive/MyDrive/mobilenet_v2_int8.xml
# Model graph (xml):   0.397 Mb
# Model weights (bin): 2.242 Mb
# Model size:          2.639 Mb
# [3/7] Benchmark FP32 model:
# [ INFO ] Count:            1302 iterations
# [ INFO ] Duration:         15035.50 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        18.28 ms
# [ INFO ]    Average:       22.91 ms
# [ INFO ]    Min:           12.46 ms
# [ INFO ]    Max:           70.82 ms
# [ INFO ] Throughput:   86.60 FPS
# [4/7] Benchmark INT8 model:
# [ INFO ] Count:            1632 iterations
# [ INFO ] Duration:         15040.77 ms
# [ INFO ] Latency:
# [ INFO ]    Median:        16.01 ms
# [ INFO ]    Average:       18.28 ms
# [ INFO ]    Min:           13.75 ms
# [ INFO ]    Max:           52.38 ms
# [ INFO ] Throughput:   108.51 FPS
# [5/7] Validate OpenVINO FP32 model:
# 100%|██████████| 31/31 [01:22<00:00,  2.65s/it]
# Accuracy @ top1: 0.198
# [6/7] Validate OpenVINO INT8 model:
# 100%|██████████| 31/31 [00:53<00:00,  1.72s/it]
# Accuracy @ top1: 0.198
# [7/7] Report:
# Accuracy drop: 0.000
# Model compression rate: 3.211
# Performance speed up (throughput mode): 1.253

# %%
|
