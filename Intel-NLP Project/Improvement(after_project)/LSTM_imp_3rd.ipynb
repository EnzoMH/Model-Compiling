# %% [markdown]
# ## 1. Library Importing

# %%
import nltk # 텍스트 데이터를 처리
import numpy as np # 말뭉치를 배열로 표현
import random
import operator
import string # 표준 파이썬 문자열을 처리
import re
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import re
from google.colab import drive
from sklearn.model_selection import train_test_split
import os
import numpy as np
from google.colab import drive

# %% [markdown]
# ## 2. Data Uploading

# %%
  # Colab에서 Google 드라이브를 마운트하기 위한 라이브러리

# 구글 드라이브 마운트
drive.mount('/content/drive')

def loadfile(path):
    X = []
    Y = []

    for label in ('0', '25', '50', '75', '100'):
        print("Loading text files for the label: " + label)

        label_path = os.path.join(path, label)
        for filename in os.listdir(label_path):
            if filename.endswith('.txt'):
                with open(os.path.join(label_path, filename), 'r', encoding='utf-8') as file:
                    text = file.read()

                # 레이블을 숫자로 변환
                if label == '0':
                    Y.append(0)
                elif label == '25':
                    Y.append(1)
                elif label == '50':
                    Y.append(2)
                elif label == '75':
                    Y.append(3)
                elif label == '100':
                    Y.append(4)

                # 텍스트 데이터를 X에 추가
                X.append(text)

    X = np.array(X)
    Y = np.array(Y)

    return X, Y

# 경로를 구글 드라이브 경로로 변경
directory_path = '/content/drive/MyDrive/likeability_final/'

# loadfile 함수 호출
X, Y = loadfile(directory_path)
# Out:
# Mounted at /content/drive
# Loading text files for the label: 0
# Loading text files for the label: 25
# Loading text files for the label: 50
# Loading text files for the label: 75
# Loading text files for the label: 100

# %%
print("X shape:", X.shape)
print("Y shape:", Y.shape)
# Out:
# X shape: (1577,)
# Y shape: (1577,)

# %%
def count_txt_files(path):
    file_counts = {}

    for label in ('0', '25', '50', '75', '100'):
        label_path = os.path.join(path, label)
        txt_files = [filename for filename in os.listdir(label_path) if filename.endswith('.txt')]
        file_counts[label] = len(txt_files)

    return file_counts

# .txt 파일 수 확인
file_counts = count_txt_files(directory_path)

# 결과 출력
for label, count in file_counts.items():
    print(f"Number of .txt files in label {label}: {count}")
# Out:
# Number of .txt files in label 0: 365
# Number of .txt files in label 25: 300
# Number of .txt files in label 50: 305
# Number of .txt files in label 75: 303
# Number of .txt files in label 100: 304

# %% [markdown]
# ## 3. 호감도 가중치 증가

# %%
# 3-1. 이모지 사용량에 따른 호감도 증가 함수
import re
import numpy as np

# 이모지 카운트 함수
def count_emojis(text):
    emoji_pattern = re.compile('['
        u'\U0001F600-\U0001F64F'  # emoticons
        u'\U0001F300-\U0001F5FF'  # symbols & pictographs
        ']', flags=re.UNICODE)
    return len(emoji_pattern.findall(text))

# 호감도 라벨링 함수
def label_likeability(text):
    emoji_count = count_emojis(text)
    exclamation_question_count = len(re.findall(r'[!?]', text))
    a_contributions = len(re.findall(r'A:', text))

    # "A"의 발화에 대한 디폴트 호감도 설정
    likeability = 75 if a_contributions > 0 else 0

    # 이모지 사용에 따른 추가적인 호감도 조정
    if emoji_count == 0 and exclamation_question_count == 0:
        likeability = 0
    elif emoji_count == 0 and exclamation_question_count >= 2:
        likeability = 25
    elif emoji_count == 1:
        likeability = 50 if exclamation_question_count >= 2 else 75
    elif emoji_count >= 2:
        likeability = 100

    return likeability

# 예시 텍스트를 사용하여 함수 테스트
example_text = """A: 안녕! 😀
B: 안녕! 😊
A: 오늘 날씨 어때? 🌤️"""
likeability = label_likeability(example_text)
print("호감도 라벨:", likeability)
# Out:
# 호감도 라벨: 100

# %%
# 3-2. 답장 속도 기반 호감도 예측
from datetime import datetime
import re
import numpy as np
# 대화 데이터를 .txt 파일에서 불러오기
conversation = []
for label in ('0', '25', '50', '75', '100'):
    label_path = os.path.join(directory_path, label)
    for filename in os.listdir(label_path):
        if filename.endswith('.txt'):
            with open(os.path.join(label_path, filename), 'r', encoding='utf-8') as file:
                conversation.extend(file.readlines())


# 호감도 레이블 생성 함수
def create_likeability_labels(conversation):
    response_times = []
    last_message_time = None
    for line in conversation:
        if line.startswith("A:") or line.startswith("B:"):
            # 시간 정보 추출 및 변환
            time_str = re.search(r'\((\d{2}):(\d{2})\)', line)
            if time_str:
                hours, minutes = map(int, time_str.groups())
                current_time = hours * 60 + minutes  # Convert to minutes
                # 답장 속도 계산
                if last_message_time is not None:
                    response_time = current_time - last_message_time
                    response_times.append(response_time)
                last_message_time = current_time
    # 평균 응답 시간 계산 및 호감도 레이블 생성
    avg_response_times = np.mean(response_times) if response_times else 0
    likeability_labels = []
    for response_time in response_times:
        if response_time <= 10:
            likeability = 100
        elif response_time <= 30:
            likeability = 75
        elif response_time <= 60:
            likeability = 50
        elif response_time <= 180:
            likeability = 25
        else:
            likeability = 0
        likeability_labels.append(likeability)
    return likeability_labels
# 대화 데이터를 기반으로 호감도 레이블 생성
likeability_labels = create_likeability_labels(conversation)

# %% [markdown]
# ## 4.데이터 정제

# %%
import re
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import wordnet
import random

# 데이터 분할
X_train, X_val, y_train, y_val = train_test_split(X, Y, test_size=0.3, random_state=42)


# 텍스트 전처리 함수 정의
def preprocess_text(text):
    # 숫자와 이모지 패턴 정의
    emoji_pattern = re.compile('['
                               u'\U0001F600-\U0001F64F'  # emoticons
                               u'\U0001F300-\U0001F5FF'  # symbols & pictographs
                               ']', flags=re.UNICODE)

    # 불용어 제거 (숫자와 이모지 제외)
    words = text.split()
    filtered_words = [word for word in words if word.isalnum() or emoji_pattern.match(word)]
    return ' '.join(filtered_words)

# 데이터셋에 텍스트 전처리 적용
X_train_preprocessed = [preprocess_text(text) for text in X_train]
X_val_preprocessed = [preprocess_text(text) for text in X_val]

# 토크나이징 및 시퀀싱
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X_train_preprocessed)

# 텍스트를 시퀀스로 변환
X_train_seq = tokenizer.texts_to_sequences(X_train_preprocessed)
X_val_seq = tokenizer.texts_to_sequences(X_val_preprocessed)

# 시퀀스 패딩
max_sequence_length = 100  # 최대 시퀀스 길이 설정
X_train_padded = pad_sequences(X_train_seq, maxlen=max_sequence_length)
X_val_padded = pad_sequences(X_val_seq, maxlen=max_sequence_length)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.optimizers import Nadam

# 기존 모델 정의
model = Sequential()
model.add(Embedding(10000, 128, input_length=max_sequence_length))  # 임베딩 차원 변경
model.add(LSTM(128, return_sequences=True, kernel_regularizer=l1_l2(l1=0.1, l2=0.1)))  # 정규화 강도 및 LSTM 유닛 수 조정
model.add(Dropout(0.5))  # Dropout 비율 조정

# Batch Normalization 추가
model.add(BatchNormalization())

model.add(LSTM(64, kernel_regularizer=l1_l2(l1=0.001, l2=0.1)))  # 두 번째 LSTM 레이어

# Batch Normalization 추가
model.add(BatchNormalization())

model.add(Dense(5, activation='softmax'))

model.compile(optimizer=Nadam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
import numpy as np

# X_train과 y_train을 NumPy 배열로 변환
X_train_np = np.array(X_train)
y_train_np = np.array(y_train)

# X_val과 y_val을 NumPy 배열로 변환
X_val_np = np.array(X_val)
y_val_np = np.array(y_val)

# 데이터의 형상(shape) 확인
print("X_train shape:", X_train_np.shape)
print("y_train shape:", y_train_np.shape)
print("X_val shape:", X_val_np.shape)
print("y_val shape:", y_val_np.shape)
# Out:
# X_train shape: (1103,)
# y_train shape: (1103,)
# X_val shape: (474,)
# y_val shape: (474,)

# %%
# 모델 훈련
history = model.fit(X_train_padded, y_train_np, epochs=100, batch_size=8, validation_data=(X_val_padded, y_val_np))
# Out:
# Epoch 1/100
# 138/138 [==============================] - 20s 115ms/step - loss: 3.2871 - accuracy: 0.2448 - val_loss: 1.5566 - val_accuracy: 0.3143
# Epoch 2/100
# 138/138 [==============================] - 7s 52ms/step - loss: 1.3716 - accuracy: 0.3708 - val_loss: 1.4010 - val_accuracy: 0.3671
# Epoch 3/100
# 138/138 [==============================] - 5s 36ms/step - loss: 1.1649 - accuracy: 0.4288 - val_loss: 1.3336 - val_accuracy: 0.4008
# Epoch 4/100
# 138/138 [==============================] - 3s 22ms/step - loss: 1.0799 - accuracy: 0.4578 - val_loss: 1.4061 - val_accuracy: 0.4093
# Epoch 5/100
# 138/138 [==============================] - 3s 23ms/step - loss: 0.9352 - accuracy: 0.5467 - val_loss: 1.4307 - val_accuracy: 0.5042
# Epoch 6/100
# 138/138 [==============================] - 3s 24ms/step - loss: 0.8444 - accuracy: 0.6201 - val_loss: 1.6455 - val_accuracy: 0.4494
# Epoch 7/100
# 138/138 [==============================] - 3s 19ms/step - loss: 0.6983 - accuracy: 0.7552 - val_loss: 1.6498 - val_accuracy: 0.5316
# Epoch 8/100
# 138/138 [==============================] - 2s 17ms/step - loss: 0.5613 - accuracy: 0.8160 - val_loss: 1.6515 - val_accuracy: 0.5295
# Epoch 9/100
# 138/138 [==============================] - 2s 17ms/step - loss: 0.4447 - accuracy: 0.8785 - val_loss: 1.5982 - val_accuracy: 0.5485
# Epoch 10/100
# 138/138 [==============================] - 2s 15ms/step - loss: 0.3737 - accuracy: 0.9066 - val_loss: 1.7063 - val_accuracy: 0.5464
# Epoch 11/100
# 138/138 [==============================] - 3s 22ms/step - loss: 0.3507 - accuracy: 0.9202 - val_loss: 1.8057 - val_accuracy: 0.5253
# Epoch 12/100
# 138/138 [==============================] - 3s 20ms/step - loss: 0.3405 - accuracy: 0.9257 - val_loss: 1.8325 - val_accuracy: 0.5591
# Epoch 13/100
# 138/138 [==============================] - 2s 18ms/step - loss: 0.2358 - accuracy: 0.9610 - val_loss: 2.0123 - val_accuracy: 0.5464
# Epoch 14/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.2148 - accuracy: 0.9655 - val_loss: 2.0389 - val_accuracy: 0.5527
# Epoch 15/100
# 138/138 [==============================] - 2s 15ms/step - loss: 0.1797 - accuracy: 0.9701 - val_loss: 1.8901 - val_accuracy: 0.5591
# Epoch 16/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1788 - accuracy: 0.9737 - val_loss: 1.9275 - val_accuracy: 0.5485
# Epoch 17/100
# 138/138 [==============================] - 3s 20ms/step - loss: 0.1724 - accuracy: 0.9692 - val_loss: 2.0067 - val_accuracy: 0.5696
# Epoch 18/100
# 138/138 [==============================] - 3s 19ms/step - loss: 0.1418 - accuracy: 0.9764 - val_loss: 2.0159 - val_accuracy: 0.5612
# Epoch 19/100
# 138/138 [==============================] - 2s 15ms/step - loss: 0.2600 - accuracy: 0.9565 - val_loss: 2.1993 - val_accuracy: 0.5338
# Epoch 20/100
# 138/138 [==============================] - 3s 19ms/step - loss: 0.2332 - accuracy: 0.9556 - val_loss: 1.8441 - val_accuracy: 0.5865
# Epoch 21/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.3014 - accuracy: 0.9483 - val_loss: 1.9314 - val_accuracy: 0.5633
# Epoch 22/100
# 138/138 [==============================] - 2s 16ms/step - loss: 0.1888 - accuracy: 0.9655 - val_loss: 1.9857 - val_accuracy: 0.5738
# Epoch 23/100
# 138/138 [==============================] - 2s 18ms/step - loss: 0.1153 - accuracy: 0.9891 - val_loss: 2.1861 - val_accuracy: 0.5696
# Epoch 24/100
# 138/138 [==============================] - 3s 19ms/step - loss: 0.1119 - accuracy: 0.9855 - val_loss: 2.1337 - val_accuracy: 0.5823
# Epoch 25/100
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0862 - accuracy: 0.9909 - val_loss: 2.1739 - val_accuracy: 0.5591
# Epoch 26/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0754 - accuracy: 0.9918 - val_loss: 2.2444 - val_accuracy: 0.5633
# Epoch 27/100
# 138/138 [==============================] - 2s 15ms/step - loss: 0.1083 - accuracy: 0.9855 - val_loss: 2.3315 - val_accuracy: 0.5570
# Epoch 28/100
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0955 - accuracy: 0.9864 - val_loss: 2.2309 - val_accuracy: 0.5717
# Epoch 29/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0990 - accuracy: 0.9864 - val_loss: 2.2188 - val_accuracy: 0.5928
# Epoch 30/100
# 138/138 [==============================] - 2s 17ms/step - loss: 0.1246 - accuracy: 0.9819 - val_loss: 2.2600 - val_accuracy: 0.5759
# Epoch 31/100
# 138/138 [==============================] - 3s 20ms/step - loss: 0.3059 - accuracy: 0.9429 - val_loss: 2.4022 - val_accuracy: 0.5443
# Epoch 32/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.2378 - accuracy: 0.9637 - val_loss: 2.1453 - val_accuracy: 0.5549
# Epoch 33/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1533 - accuracy: 0.9819 - val_loss: 2.0759 - val_accuracy: 0.5781
# Epoch 34/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0975 - accuracy: 0.9873 - val_loss: 2.1935 - val_accuracy: 0.5612
# Epoch 35/100
# 138/138 [==============================] - 2s 16ms/step - loss: 0.0827 - accuracy: 0.9882 - val_loss: 2.2045 - val_accuracy: 0.5759
# Epoch 36/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1082 - accuracy: 0.9837 - val_loss: 2.2749 - val_accuracy: 0.5359
# Epoch 37/100
# 138/138 [==============================] - 3s 18ms/step - loss: 0.0809 - accuracy: 0.9918 - val_loss: 2.3688 - val_accuracy: 0.5443
# Epoch 38/100
# 138/138 [==============================] - 3s 20ms/step - loss: 0.1266 - accuracy: 0.9755 - val_loss: 2.3695 - val_accuracy: 0.5380
# Epoch 39/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.1033 - accuracy: 0.9891 - val_loss: 2.3210 - val_accuracy: 0.5422
# Epoch 40/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0832 - accuracy: 0.9882 - val_loss: 2.3245 - val_accuracy: 0.5527
# Epoch 41/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0711 - accuracy: 0.9937 - val_loss: 2.3601 - val_accuracy: 0.5549
# Epoch 42/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0555 - accuracy: 0.9937 - val_loss: 2.5376 - val_accuracy: 0.5485
# Epoch 43/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.7465 - accuracy: 0.7969 - val_loss: 2.1908 - val_accuracy: 0.4641
# Epoch 44/100
# 138/138 [==============================] - 3s 18ms/step - loss: 0.4016 - accuracy: 0.9338 - val_loss: 2.3112 - val_accuracy: 0.5253
# Epoch 45/100
# 138/138 [==============================] - 2s 18ms/step - loss: 0.2334 - accuracy: 0.9755 - val_loss: 2.2883 - val_accuracy: 0.5000
# Epoch 46/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.2027 - accuracy: 0.9710 - val_loss: 2.3913 - val_accuracy: 0.5338
# Epoch 47/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1586 - accuracy: 0.9819 - val_loss: 2.3165 - val_accuracy: 0.5380
# Epoch 48/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1344 - accuracy: 0.9846 - val_loss: 2.4225 - val_accuracy: 0.5274
# Epoch 49/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1181 - accuracy: 0.9873 - val_loss: 2.4827 - val_accuracy: 0.5380
# Epoch 50/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.1354 - accuracy: 0.9810 - val_loss: 2.5077 - val_accuracy: 0.5464
# Epoch 51/100
# 138/138 [==============================] - 3s 24ms/step - loss: 0.1199 - accuracy: 0.9864 - val_loss: 2.5335 - val_accuracy: 0.5338
# Epoch 52/100
# 138/138 [==============================] - 2s 16ms/step - loss: 0.1204 - accuracy: 0.9855 - val_loss: 2.4556 - val_accuracy: 0.5570
# Epoch 53/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.1303 - accuracy: 0.9828 - val_loss: 2.4197 - val_accuracy: 0.5527
# Epoch 54/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.1006 - accuracy: 0.9891 - val_loss: 2.4988 - val_accuracy: 0.5422
# Epoch 55/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0989 - accuracy: 0.9882 - val_loss: 2.4417 - val_accuracy: 0.5443
# Epoch 56/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0940 - accuracy: 0.9891 - val_loss: 2.5460 - val_accuracy: 0.5464
# Epoch 57/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0891 - accuracy: 0.9882 - val_loss: 2.5968 - val_accuracy: 0.5422
# Epoch 58/100
# 138/138 [==============================] - 3s 20ms/step - loss: 0.0890 - accuracy: 0.9891 - val_loss: 2.6021 - val_accuracy: 0.5464
# Epoch 59/100
# 138/138 [==============================] - 2s 16ms/step - loss: 0.0868 - accuracy: 0.9900 - val_loss: 2.5827 - val_accuracy: 0.5443
# Epoch 60/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0858 - accuracy: 0.9909 - val_loss: 2.5205 - val_accuracy: 0.5443
# Epoch 61/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0839 - accuracy: 0.9900 - val_loss: 2.6748 - val_accuracy: 0.5401
# Epoch 62/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0930 - accuracy: 0.9864 - val_loss: 2.7540 - val_accuracy: 0.5401
# Epoch 63/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.1637 - accuracy: 0.9692 - val_loss: 2.4875 - val_accuracy: 0.5295
# Epoch 64/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.1633 - accuracy: 0.9701 - val_loss: 2.3505 - val_accuracy: 0.5485
# Epoch 65/100
# 138/138 [==============================] - 3s 19ms/step - loss: 0.1177 - accuracy: 0.9819 - val_loss: 2.4507 - val_accuracy: 0.5338
# Epoch 66/100
# 138/138 [==============================] - 3s 19ms/step - loss: 0.0907 - accuracy: 0.9891 - val_loss: 2.7492 - val_accuracy: 0.5443
# Epoch 67/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0775 - accuracy: 0.9882 - val_loss: 2.8014 - val_accuracy: 0.5464
# Epoch 68/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0847 - accuracy: 0.9882 - val_loss: 2.7036 - val_accuracy: 0.5591
# Epoch 69/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0690 - accuracy: 0.9882 - val_loss: 2.7927 - val_accuracy: 0.5527
# Epoch 70/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0554 - accuracy: 0.9918 - val_loss: 2.6824 - val_accuracy: 0.5485
# Epoch 71/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0578 - accuracy: 0.9937 - val_loss: 2.7235 - val_accuracy: 0.5422
# Epoch 72/100
# 138/138 [==============================] - 3s 18ms/step - loss: 0.0585 - accuracy: 0.9946 - val_loss: 2.8568 - val_accuracy: 0.5675
# Epoch 73/100
# 138/138 [==============================] - 3s 19ms/step - loss: 0.0483 - accuracy: 0.9946 - val_loss: 2.8054 - val_accuracy: 0.5506
# Epoch 74/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0459 - accuracy: 0.9946 - val_loss: 3.1457 - val_accuracy: 0.5654
# Epoch 75/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0538 - accuracy: 0.9937 - val_loss: 2.8338 - val_accuracy: 0.5675
# Epoch 76/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.1391 - accuracy: 0.9746 - val_loss: 3.0195 - val_accuracy: 0.4747
# Epoch 77/100
# 138/138 [==============================] - 2s 15ms/step - loss: 0.2071 - accuracy: 0.9692 - val_loss: 2.5765 - val_accuracy: 0.5549
# Epoch 78/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.1175 - accuracy: 0.9773 - val_loss: 2.2630 - val_accuracy: 0.5570
# Epoch 79/100
# 138/138 [==============================] - 2s 16ms/step - loss: 0.1162 - accuracy: 0.9801 - val_loss: 2.6875 - val_accuracy: 0.5443
# Epoch 80/100
# 138/138 [==============================] - 2s 17ms/step - loss: 0.0759 - accuracy: 0.9873 - val_loss: 2.7164 - val_accuracy: 0.5506
# Epoch 81/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0625 - accuracy: 0.9937 - val_loss: 2.6438 - val_accuracy: 0.5633
# Epoch 82/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0549 - accuracy: 0.9955 - val_loss: 2.8226 - val_accuracy: 0.5633
# Epoch 83/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0440 - accuracy: 0.9964 - val_loss: 2.7605 - val_accuracy: 0.5654
# Epoch 84/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0676 - accuracy: 0.9909 - val_loss: 2.6870 - val_accuracy: 0.5401
# Epoch 85/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0792 - accuracy: 0.9864 - val_loss: 2.6684 - val_accuracy: 0.5802
# Epoch 86/100
# 138/138 [==============================] - 2s 15ms/step - loss: 0.0548 - accuracy: 0.9946 - val_loss: 2.6084 - val_accuracy: 0.5654
# Epoch 87/100
# 138/138 [==============================] - 3s 19ms/step - loss: 0.0419 - accuracy: 0.9955 - val_loss: 2.7021 - val_accuracy: 0.5675
# Epoch 88/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0499 - accuracy: 0.9937 - val_loss: 2.4583 - val_accuracy: 0.5591
# Epoch 89/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0694 - accuracy: 0.9909 - val_loss: 2.8053 - val_accuracy: 0.5633
# Epoch 90/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1010 - accuracy: 0.9819 - val_loss: 2.8402 - val_accuracy: 0.5591
# Epoch 91/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0717 - accuracy: 0.9900 - val_loss: 2.4799 - val_accuracy: 0.5802
# Epoch 92/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0418 - accuracy: 0.9955 - val_loss: 2.7344 - val_accuracy: 0.5738
# Epoch 93/100
# 138/138 [==============================] - 2s 17ms/step - loss: 0.0397 - accuracy: 0.9946 - val_loss: 2.7149 - val_accuracy: 0.5907
# Epoch 94/100
# 138/138 [==============================] - 2s 17ms/step - loss: 0.0492 - accuracy: 0.9946 - val_loss: 2.5463 - val_accuracy: 0.5781
# Epoch 95/100
# 138/138 [==============================] - 2s 16ms/step - loss: 0.0493 - accuracy: 0.9946 - val_loss: 2.5747 - val_accuracy: 0.5738
# Epoch 96/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0378 - accuracy: 0.9964 - val_loss: 2.8023 - val_accuracy: 0.5781
# Epoch 97/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0358 - accuracy: 0.9964 - val_loss: 2.7094 - val_accuracy: 0.5823
# Epoch 98/100
# 138/138 [==============================] - 2s 13ms/step - loss: 0.0352 - accuracy: 0.9955 - val_loss: 2.6722 - val_accuracy: 0.5865
# Epoch 99/100
# 138/138 [==============================] - 2s 14ms/step - loss: 0.0351 - accuracy: 0.9955 - val_loss: 2.7926 - val_accuracy: 0.5865
# Epoch 100/100
# 138/138 [==============================] - 2s 17ms/step - loss: 0.0406 - accuracy: 0.9955 - val_loss: 2.9069 - val_accuracy: 0.5654

# %% [markdown]
# ## 5.평가지표

# %%
import matplotlib.pyplot as plt

# Accuracy 그래프
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Loss 그래프
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# 모델 예측
y_pred = model.predict(X_val_padded)
y_pred_classes = np.argmax(y_pred, axis=1)

# Confusion Matrix 생성
cm = confusion_matrix(y_val_np, y_pred_classes)

# 시각화
sns.heatmap(cm, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# 15/15 [==============================] - 1s 7ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_val_np, y_pred_classes)
precision = precision_score(y_val_np, y_pred_classes, average='macro')
recall = recall_score(y_val_np, y_pred_classes, average='macro')
f1 = f1_score(y_val_np, y_pred_classes, average='macro')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.5654008438818565
# Precision: 0.6086141352395867
# Recall: 0.5576814026370476
# F1 Score: 0.567401472457373

# %%
import time
from tensorflow.keras.models import load_model
import os

# 모델 저장 및 크기 확인 (MB 단위로 변환)
model.save('lstm_likeability.h5')
model_size = os.path.getsize('lstm_likeability.h5') / (1024 * 1024)  # Bytes to Megabytes
print("Model Size:", model_size, "MB")

# 추론 시간 측정 (초 단위)
start_time = time.time()
y_pred = model.predict(X_val_padded[0:1])
end_time = time.time()
inference_time = end_time - start_time
print("Inference Time:", round(inference_time, 4),"seconds")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model Size: 16.771263122558594 MB
# 1/1 [==============================] - 0s 110ms/step
# Inference Time: 0.2898 seconds
